# %%
import requests
import pprint
import pandas as pd
import json
from urllib.parse import urlparse
import urllib
import re
from tqdm import tqdm
import time

# %% [markdown]
# ## Data Acquisition

# %% [markdown]
# ### English Language Only

# %%
#JSON Escape Error fix by Blairg23
#https://stackoverflow.com/questions/1505454/python-json-loads-chokes-on-escapes
def fix_JSON(json_message=None):
    result = None
    try:        
        result = json.loads(json_message)
    except Exception as e:      
        # Find the offending character index:
        idx_to_replace = int(str(e).split(' ')[-1].replace(')', ''))        
        # Remove the offending character:
        json_message = list(json_message)
        json_message[idx_to_replace] = ' '
        new_message = ''.join(json_message)     
        return fix_JSON(json_message=new_message)
    return result

# %%
#Input fixed parameters
parameters = {
    "query": '"belt%20and%20road"OR"one%20belt%20one%20road"%20sourcelang:eng',
    "startdatetime": 20170525000000,
    "enddatetime": 20170525235959,
    "format": "JSON",
    "maxrecords": 250,
    "sort": "DateDesc",
    "mode": "ToneChart"
}
url = "https://api.gdeltproject.org/api/v2/doc/doc?" + urllib.parse.urlencode(parameters, safe='%():+')
response = requests.get(url)

# %%
output = fix_JSON(response.content.decode('utf8'))
pprint.pprint(output['tonechart'])
# Out:
# [{'bin': -8,
#   'count': 1,
#   'toparts': [{'title': 'Sinkhole causes road closure in Bakersfield , '
#                         'California -- Earth Changes',
#                'url': 'https://www.sott.net/article/351957-Sinkhole-causes-road-closure-in-Bakersfield-California'}]},
#  {'bin': -7,
#   'count': 3,
#   'toparts': [{'title': 'China denies UN report on CPEC',
#                'url': 'http://www.nerve.in/news:2535003921070'},
#               {'title': 'Pakistan captures Taliban leader blamed for three '
#                         'bombings in restive southwest',
#                'url': 'http://www.businessinsider.com/r-pakistan-captures-taliban-leader-blamed-for-three-bombings-in-restive-southwest-2017-5'},
#               {'title': 'China dismisses Moody downgrade as  inappropriate  ',
#                'url': 'http://en.people.cn/n3/2017/0525/c90000-9220520.html'}]},
#  {'bin': -6,
#   'count': 8,
#   'toparts': [{'title': 'China denies UN report on CPEC',
#                'url': 'http://www.business-standard.com/article/news-ians/china-denies-un-report-on-cpec-117052500996_1.html'},
#               {'title': 'China downplays UN report stating CPEC may fuel geo',
#                'url': 'http://www.firstpost.com/india/china-downplays-un-report-stating-cpec-may-fuel-geo-political-tensions-in-south-asia-3480973.html'},
#               {'title': 'India',
#                'url': 'http://www.ibtimes.co.in/india-pak-tensions-could-escalate-due-china-pakistan-economic-corridor-warns-un-728027'},
#               {'title': 'CPEC may lead to increased tensions between India and '
#                         'Pakistan , says UN report',
#                'url': 'http://indianexpress.com/article/world/cpec-may-lead-to-increased-tensions-between-india-and-pakistan-says-un-report-4672707/'},
#               {'title': 'CPEC : Pakistan Wins War Against India Without Even '
#                         'Starting One',
#                'url': 'http://www.valuewalk.com/2017/05/cpec-pakistan-wins-war-vs-india/'},
#               {'title': 'China dismisses Moody downgrade as  inappropriate  ',
#                'url': 'HTTP://en.ce.cn/main/latest/201705/25/t20170525_23223753.shtml'},
#               {'title': 'Economic Watch : Moody downgrade of China ratings '
#                         'draws distrust , faces test',
#                'url': 'http://news.xinhuanet.com/english/2017-05/25/c_136312203.htm'},
#               {'title': 'Moody downgrade of China ratings draws distrust , '
#                         'faces test',
#                'url': 'http://www.ecns.cn/business/2017/05-25/258968.shtml'}]},
#  {'bin': -5,
#   'count': 18,
#   'toparts': [{'title': 'China denies UN report on CPEC',
#                'url': 'http://news.webindia123.com/news/Articles/Business/20170525/3113146.html'},
#               {'title': 'China denies UN report on CPEC',
#                'url': 'http://nripress.com/china-denies-un-report-on-cpec/'},
#               {'title': 'China denies UN report on CPEC',
#                'url': 'http://zeenews.india.com/world/china-denies-un-report-on-cpec-2008942.html'},
#               {'title': 'Chinese firms wary of political risks on Xi  Belt and '
#                         'Road  plan',
#                'url': 'http://www.gulf-times.com/story/550071/Chinese-firms-wary-of-political-risks-on-Xi-s-Belt'},
#               {'title': 'Kidnapping highlights risks along China',
#                'url': 'http://www.globaltimes.cn/content/1048723.shtml'},
#               {'title': 'Two Chinese nationals kidnapped in Pakistan',
#                'url': 'http://www.chinaeconomicreview.com/two-chinese-nationals-kidnapped-pakistan'},
#               {'title': 'Moodys Cuts Hong Kong Rating Following China '
#                         'Downgrade',
#                'url': 'http://profit.ndtv.com/news/international-business/article-moodys-cuts-hong-kong-rating-following-china-downgrade-1703696?pfrom=Defence_profit2016'},
#               {'title': 'Moody slashes Hong Kong rating following China cut',
#                'url': 'http://www.deccanherald.com/content/613491/moodys-slashes-hong-kong-rating.html'},
#               {'title': 'Moodys Cuts Hong Kong Rating Following China '
#                         'Downgrade',
#                'url': 'http://profit.ndtv.com/news/international-business/article-moodys-cuts-hong-kong-rating-following-china-downgrade-1703696'},
#               {'title': 'Moody slashes Hong Kong rating following China cut',
#                'url': 'http://www.thehindubusinessline.com/news/world/moodys-slashes-hong-kong-rating-following-china-cut/article9712229.ece'}]},
#  {'bin': -4,
#   'count': 37,
#   'toparts': [{'title': 'China dismisses UN body warning on Pakistan corridor '
#                         'causing tension with India ',
#                'url': 'http://www.hindustantimes.com/world-news/china-dismisses-un-body-s-warning-on-pakistan-corridor-causing-tension-with-india/story-ebYXCILF2v7YlbVzUYY3bO.html'},
#               {'title': 'Moody cuts Hong Kong credit rating due to  '
#                         'tightening  links with mainland',
#                'url': 'http://www.huewire.com/moodys-cuts-hong-kongs-credit-rating-due-to-tightening-links-with-mainland/'},
#               {'title': 'Hong Kong govt dismisses Moody rating cut',
#                'url': 'http://www.asianews.network/content/hong-kong-govt-dismisses-moodys-rating-cut-46731'},
#               {'title': 'Moody slashes Hong Kong rating following China cut',
#                'url': 'http://gulfnews.com/business/economy/moody-s-slashes-hong-kong-rating-following-china-cut-1.2033038'},
#               {'title': 'Moody slashes Hong Kong rating',
#                'url': 'http://www.arabnews.com/node/1104796/business-economy'},
#               {'title': 'Moody slashes Hong Kong rating following China cut',
#                'url': 'http://www.business-standard.com/article/pti-stories/moody-s-slashes-hong-kong-rating-following-china-cut-117052500302_1.html'},
#               {'title': 'Flash',
#                'url': 'http://www.france24.com/en/20170525-moodys-slashes-hong-kong-rating-following-china-cut'},
#               {'title': 'Moody Slashes Hong Kong Rating Following China Cut',
#                'url': 'http://www.news18.com/news/business/moodys-slashes-hong-kong-rating-following-china-cut-1411993.html'},
#               {'title': 'Moody slashes Hong Kong rating following China cut',
#                'url': 'http://zeenews.india.com/international-business/moodys-slashes-hong-kong-rating-following-china-cut-2008649.html'},
#               {'title': 'Hong Kong rejects credit downgrade over links to '
#                         'China ',
#                'url': 'http://www.dw.com/en/hong-kong-rejects-credit-downgrade-over-links-to-china/a-38978198'}]},
#  {'bin': -3,
#   'count': 50,
#   'toparts': [{'title': 'Thailand News . Net',
#                'url': 'http://www.thailandnews.net/news/253315866/cpec-may-fuel-indo-pak-tension-un-report'},
#               {'title': 'Laos News . Net',
#                'url': 'http://www.laosnews.net/news/253315866/cpec-may-fuel-indo-pak-tension-un-report'},
#               {'title': 'China imperial ambitions can rack up a huge cost',
#                'url': 'http://gulfnews.com/business/analysis/china-s-imperial-ambitions-can-rack-up-a-huge-cost-1.2033324'},
#               {'title': 'Moody downgrades Hong Kong credit ratings post China '
#                         'credit score cut',
#                'url': 'http://www.newsnation.in/business-news/moodys-downgrades-hong-kongs-credit-ratings-post-chinas-credit-score-cut-article-172223.html'},
#               {'title': 'Moody ’ s slashes Hong Kong rating following China '
#                         'cut',
#                'url': 'http://www.thenewage.co.za/moodys-slashes-hong-kong-rating-following-china-cut/'},
#               {'title': 'Hong Kong hits back at Moody for cutting credit '
#                         'rating',
#                'url': 'https://www.enca.com/money/hong-kong-hits-back-at-moodys-for-cutting-its-credit-rating'},
#               {'title': 'Moody ’ s slashes Hong Kong rating following China '
#                         'cut',
#                'url': 'http://www.ann7.com/moodys-slashes-hong-kong-rating-following-china-cut/'},
#               {'title': 'Moody slashes Hong Kong rating following China cut',
#                'url': 'http://e.vnexpress.net/news/business/economy/moody-s-slashes-hong-kong-rating-following-china-cut-3590134.html'},
#               {'title': 'Hong Kong hits back at Moody for cutting credit '
#                         'rating',
#                'url': 'http://www.enca.com/money/hong-kong-hits-back-at-moodys-for-cutting-its-credit-rating'},
#               {'title': 'Moody slashes Hong Kong rating following China cut',
#                'url': 'http://www.chinapost.com.tw/business/asia/hong-kong/2017/05/25/497906/moodys-slashes.htm'}]},
#  {'bin': -2,
#   'count': 26,
#   'toparts': [{'title': 'Managing risk along the Belt and Road of opportunity',
#                'url': 'http://www.lexology.com/library/detail.aspx?g=09968376-c58e-4c32-b82b-dd8c66b5a068'},
#               {'title': 'Singapore Star',
#                'url': 'http://www.singaporestar.com/article/253334832/singapores-role-in-belt-and-road-initiative-shouldnt-be-dismissed'},
#               {'title': 'With China Belt and Road conference , few noticed the '
#                         'AIIB added another 7 nations to its coalition',
#                'url': 'https://thedailycoin.org/2017/05/24/chinas-belt-road-conference-noticed-aiib-added-another-7-nations-coalition/'},
#               {'title': 'CPEC Likely to Cause More India',
#                'url': 'https://kashmirobserver.net/2017/local-news/cpec-likely-cause-more-india-pakistan-tension-un-18287'},
#               {'title': 'New EU anti',
#                'url': 'http://china.org.cn/china/Off_the_Wire/2017-05/25/content_40884239.htm'},
#               {'title': 'New EU anti',
#                'url': 'http://news.xinhuanet.com/english/2017-05/25/c_136312223.htm'},
#               {'title': 'New EU anti',
#                'url': 'http://www.ecns.cn/2017/05-25/258963.shtml'},
#               {'title': 'China Hits Speed Wobbles Driving the Silk Road '
#                         'through Sri Lanka',
#                'url': 'https://international.thenewslens.com/article/69112'},
#               {'title': 'CPEC may create more India',
#  {'bin': 3,
#   'count': 19,
#   'toparts': [{'title': 'A Lecture on  China & One Road one Belt  initiative '
#                         'held in Sarajevo',
#                'url': 'http://www.sarajevotimes.com/?p=120621'},
#               {'title': 'China stresses role of Belt and Road Initiative in UN '
#                         '2030 Agenda',
#                'url': 'http://english.jschina.com.cn/./20946/201705/t20170525_4140691.shtml'},
#               {'title': 'Vice Chairman of Standing Committee of Chinese '
#                         'National People Congress pays official visit to '
#                         'Turkmenistan',
#                'url': 'http://akipress.com/news:592839/'},
#               {'title': 'Japan Inc sees better opportunities beyond China  '
#                         'Belt and Road  ',
#                'url': 'http://www.thefiscaltimes.com/latestnews/2017/05/24/Japan-Inc-sees-better-opportunities-beyond-Chinas-Belt-and-Road-0'},
#               {'title': 'Japan Inc sees better opportunities beyond China  '
#                         'Belt and Road  ',
#                'url': 'http://wsau.com/news/articles/2017/may/25/japan-inc-sees-better-opportunities-beyond-chinas-belt-and-road/'},
#               {'title': 'Japan Inc sees better opportunities beyond China ’ s  '
#                         'Belt and Road  ',
#                'url': 'http://indianexpress.com/article/world/japan-inc-sees-better-opportunities-beyond-chinas-belt-and-road-4672791/'},
#               {'title': 'China urges Nigeria to tap into $43 . 5bn Silk Road '
#                         'Fund',
#                'url': 'http://uncova.com/china-urges-nigeria-to-tap-into-435bn-silk-road-fund'},
#               {'title': 'Executives in Texas welcome B & R initiative , '
#                         'calling for expanded cooperation',
#                'url': 'http://www.globaltimes.cn/content/1048712.shtml'},
#               {'title': 'IBA Karachi , Shanghai University to collaboratively '
#                         'offer finance program',
#                'url': 'https://www.dawn.com/news/1335341/iba-karachi-shanghai-university-to-collaboratively-offer-finance-program'},
#               {'title': 'Hong Kong is super',
#                'url': 'http://7thspace.com/headlines/535613/hong_kong_is_super_connector_bridging_mainland_and_global_markets_under_belt_and_road_initiative.html'}]},
#  {'bin': 4,
#   'count': 17,
#   'toparts': [{'title': 'Welcome to the BVI London Office Website',
#                'url': 'http://www.bvi.org.uk/government/pressreleases/bvifinanceconnectscompaniestobeltandroadinitiative'},
#               {'title': 'China urges Nigeria to tap into $43 . 5bn Silk Road '
#                         'Fund',
#                'url': 'http://sunnewsonline.com/china-urges-nigeria-to-tap-into-43-5bn-silk-road-fund/'},
#               {'title': 'Meeting with Chinese Foreign Minister Wang Yi • '
#                         'President of Russia',
#                'url': 'http://en.kremlin.ru/events/president/news/54576'},
#               {'title': 'Cross',
#                'url': 'http://fujian.chinadaily.com.cn/2017-05/25/content_29488587.htm'},
#               {'title': 'Presidency of People Republic of China',
#                'url': 'http://www.4-traders.com/news/Presidency-of-People-Republic-of-China-Premier-Li-seeks-to-enhance-China-Hungary-ties--24492035/'},
#               {'title': 'Seize  The Belt and the Road  development '
#                         'opportunities JAC accelerates its step into Argentina '
#                         'market',
#                'url': 'http://www.automotiveworld.com/news-releases/seize-belt-road-development-opportunities-jac-accelerates-step-argentina-market/'},
#               {'title': 'Seize  The Belt and the Road  development '
#                         'opportunities JAC accelerates its step into Argentina '
#                         'market',
#                'url': 'https://www.automotiveworld.com/news-releases/seize-belt-road-development-opportunities-jac-accelerates-step-argentina-market/'},
#               {'title': 'Bahrain News Agency',
#                'url': 'http://www.bna.bh/portal/en/news/787744'},
#               {'title': 'HK , Shanghai Hold Meeting to Enhance Financial Co',
#                'url': 'https://insurancenewsnet.com/oarticle/hk-shanghai-hold-meeting-to-enhance-financial-co-operation'},
#               {'title': 'D & G Technology Awarded Quam IR Awards 2016',
#                'url': 'http://foreignaffairs.co.nz/2017/05/25/dg-technology-awarded-quam-ir-awards-2016-main-board-category/'}]},
#  {'bin': 5,
#   'count': 3,
#   'toparts': [{'title': 'Wang Yi Talks about Feelings of His Visits to Four '
#                         'African Countries',
#                'url': 'http://www.fmprc.gov.cn/mfa_eng/zxxx_662805/t1465162.shtml'},
#               {'title': 'Wang Yi Talks about Feelings of His Visits to Four '
#                         'African Countries – ForeignAffairs . co . nz',
#                'url': 'http://foreignaffairs.co.nz/2017/05/25/wang-yi-talks-about-feelings-of-his-visits-to-four-african-countries/'},
#               {'title': 'Getting into the Swing -- Beijing Review',
#                'url': 'http://www.bjreview.com.cn/./Lifestyle/201705/t20170525_800097012.html'}]},
#  {'bin': 6, 'count': 0, 'toparts': []},
#  {'bin': 7,
#   'count': 2,
#   'toparts': [{'title': 'Development success of Vietnam and China is each '
#                         'other opportunity : Vietnamese president',
#                'url': 'http://www.globaltimes.cn/content/1048586.shtml'},
#               {'title': 'Majestic Princess begins journey to China along the '
#                         'Silk Road Sea Route',
#                'url': 'http://www.traveldailynews.asia/news/article/65089/majestic-princess-begins-journey-to'}]},
#  {'bin': 8,
#   'count': 1,
#   'toparts': [{'title': 'Majestic Princess Begins Silk Road Journey',
#                'url': 'https://www.cruiseindustrynews.com/cruise-news/17042-majestic-princess-begins-silk-road-journey.html'}]}]

# %%
#Input fixed parameters
parameters = {
    "query": '"belt%20and%20road"OR"one%20belt%20one%20road"%20sourcelang:eng',
    "startdatetime": 20170101000000,
    "enddatetime": 20170101235959,
    "format": "JSON",
    "maxrecords": 250,
    "sort": "DateDesc",
    "mode": "ToneChart"
}

for year in range(2023,2024):
    results[str(year)] = []
    
    #Range Array for parameters
    r = pd.date_range(str(year)+'0101',str(year)+'1231')
    r = r.format(formatter=lambda x: x.strftime('%Y%m%d'))
    #Input parameters according to dates
    for day in tqdm(range(len(r))):
        time.sleep(5.5)
        parameters["startdatetime"] = r[day] + '000000'
        parameters["enddatetime"] = r[day] + '235959'
        
        url = "https://api.gdeltproject.org/api/v2/doc/doc?" + urllib.parse.urlencode(parameters, safe='%():+')
        response = requests.get(url)
        
        #Prevent JSON escape errors
        output = fix_JSON(response.content.decode('utf8'))
        if len(output)!=0:
            for length in range(len(output['tonechart'])):
                if len(output['tonechart'][length]['toparts']) !=0:
                    for num_of_articles in range(len(output['tonechart'][length]['toparts'])):
                        details = {"title": output['tonechart'][length]['toparts'][num_of_articles]['title'],
                                    "url": output['tonechart'][length]['toparts'][num_of_articles]['url'],
                                    "date": r[day],
                                    "tone": output['tonechart'][length]['bin']}
                        results[str(year)].append(details)

# %%
# Save raw JSON data
#with open('./Final Data/1 - raw_data.json', 'w', encoding='utf-8') as f:
#        json.dump(results, f, indent=4, default=str)

# %% [markdown]
# #### Label articles with domain and country source using API

# %%
parameters = {
    "query": 'domain:global.chinadaily.com.cn',
    "format": "JSON",
    "maxrecords": 1,
    "mode": "ArtList"
}

# %%
unlabelled_domains = []
labelled_domains = {}
unlabelled_count = 0

# %%
from time import sleep
for year in range(2019,2024):
    year = str(year)
    for num in tqdm(range(len(results[year]))):
        #Get URL domain
        domain = str(urlparse(results[year][num]['url']).netloc)
        domain = re.sub(r'www.', '', domain)

        results[year][num]['domain'] = domain

        #Check domain with unlabelled domains first (Smaller dataset)
        if domain in unlabelled_domains:
            unlabelled_count+=1

        #Check domain with local data
        elif domain in labelled_domains:
            results[year][num]['sourcecountry'] = labelled_domains[domain]

        else:
            #Get sourcecountry from API
            sleep(5.5)
            parameters['query'] = 'domain:'+ domain
            response = requests.get("https://api.gdeltproject.org/api/v2/doc/doc", params=parameters)
            output = fix_JSON(response.content.decode('utf8'))
            if len(output) !=0:
                results[year][num]['sourcecountry'] = output['articles'][0]['sourcecountry']
                labelled_domains[domain] = output['articles'][0]['sourcecountry']
            else:
                unlabelled_domains.append(domain)
                unlabelled_count+=1
# Out:
# 100%|██████████| 34471/34471 [2:14:29<00:00,  4.27it/s]
# 100%|██████████| 24081/24081 [1:15:18<00:00,  5.33it/s]
# 100%|██████████| 27435/27435 [51:41<00:00,  8.85it/s]
# 100%|██████████| 27183/27183 [42:55<00:00, 10.56it/s]
# 100%|██████████| 15147/15147 [25:44<00:00,  9.80it/s]

# %%
#with open('./Final Data/2 - sourcecountry.json', 'w', encoding='utf-8') as f:
        #json.dump(results, f, indent=4, default=str)

# %% [markdown]
# ### All languages for NATO

# %%
nato_countries_short = ['AL', 'BE', 'BU', 'CA', 'HR', 'EZ', 'DA', 'EN', 'FI', 'FR',
                        'GM', 'GR', 'HU', 'IC', 'IT', 'LG', 'LH', 'LU', 'MJ', 'NL',
                        'MK', 'NO', 'PL', 'PO', 'RO', 'LO', 'SI', 'SP', 'TU', 'GB',
                        'US']

# %%
import urllib.parse
parameters["query"] = '"belt and road"+"one belt one road" (sourcecountry:%s)' %' OR sourcecountry:'.join(nato_countries_short[20:30])#Query to search
url = "https://api.gdeltproject.org/api/v2/doc/doc/?" + urllib.parse.urlencode(parameters, safe='():+')
response = requests.get(url)

# %%
import urllib.parse

#Input fixed parameters
parameters = {
"query": '"belt and road"+"one belt one road"', #Query to search
"startdatetime": '',
"enddatetime": '',
"format": "JSON",
"maxrecords": 250,
"sort": "DateDesc",
"mode": "ToneChart"}

nato_countries_short = ['AL', 'BE', 'BU', 'CA', 'HR', 'EZ', 'DA', 'EN', 'FI', 'FR',
                        'GM', 'GR', 'HU', 'IC', 'IT', 'LG', 'LH', 'LU', 'MJ', 'NL',
                        'MK', 'NO', 'PL', 'PO', 'RO', 'LO', 'SI', 'SP', 'TU', 'GB',
                        'US']


for x in [0,10,20]:
    for year in range(2017,2024):
        results[str(year)] = []
        

        #Range Array for parameters
        r = pd.date_range(str(year)+'0101',str(year)+'1231')
        r = r.format(formatter=lambda x: x.strftime('%Y%m%d'))

        

        #Input parameters according to dates
        for day in tqdm(range(len(r))):
            time.sleep(5.5)
            parameters["startdatetime"] = r[day] + '000000'
            parameters["enddatetime"] = r[day] + '235959'
            
            parameters["query"] = '"belt and road"+"one belt one road" (sourcecountry:%s)' %' OR sourcecountry:'.join(nato_countries_short[x:x+10])#Query to search
            url = "https://api.gdeltproject.org/api/v2/doc/doc/?" + urllib.parse.urlencode(parameters, safe='():+')
            response = requests.get(url)
            
            #Prevent JSON escape errors
            output = fix_JSON(response.content.decode('utf8'))
            if len(output)!=0:
                for length in range(len(output['tonechart'])):
                    if len(output['tonechart'][length]['toparts']) !=0:
                        for num_of_articles in range(len(output['tonechart'][length]['toparts'])):
                            details = {"title": output['tonechart'][length]['toparts'][num_of_articles]['title'],
                                        "url": output['tonechart'][length]['toparts'][num_of_articles]['url'],
                                        "date": r[day],
                                        "tone": output['tonechart'][length]['bin']}
                            results[str(year)].append(details)

# %%
with open('./additional_data/nato_results2.json', 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=4, default=str)

# %%
from urllib.parse import urlparse
import re

unlabelled_domains = []
labelled_domains = {}
unlabelled_count = 0

parameters = {
    "query": 'domain:global.chinadaily.com.cn',
    "format": "JSON",
    "maxrecords": 1,
    "mode": "ArtList"
}

# %%
year=2023
year = str(year)
for num in range(len(results[year])):
    #Get URL domain
    domain = str(urlparse(results[year][num]['url']).netloc)
    domain = re.sub(r'www.', '', domain)

    results[year][num]['domain'] = domain

    #Check domain with unlabelled domains first (Smaller dataset)
    if domain in unlabelled_domains:
        unlabelled_count+=1

    #Check domain with local data
    elif domain in labelled_domains:
        results[year][num]['sourcecountry'] = labelled_domains[domain]

    else:
        #Get sourcecountry from API
        parameters['query'] = 'domain:'+ domain
        response = requests.get("https://api.gdeltproject.org/api/v2/doc/doc", params=parameters)
        output = fix_JSON(response.content.decode('utf8'))
        if len(output) !=0:
            results[year][num]['sourcecountry'] = output['articles'][0]['sourcecountry']
            labelled_domains[domain] = output['articles'][0]['sourcecountry']
        else:
            unlabelled_domains.append(domain)
            unlabelled_count+=1

# %%
year = str(2017)
for num in range(len(results[year])):
    country = results[year][num]['sourcecountry']
    tone = results[year][num]['tone']
    country_df.loc[(country_df['Country']==country) & (country_df['Year']==str(year)), 'Average Tone'] += int(tone)

country_df["Average Tone"]=country_df["Average Tone"].astype(float)
for num in range(len(country_df)):
    country_df.iat[num,4] = country_df.iat[num,4] / country_df.iat[num,1]

# %%
country_df = pd.DataFrame(columns=['Country','Count','Year'])
country_df["Count"]=country_df["Count"].astype(float)
for year in range(2017,2023):
    country_count = {}
    year = str(year)
    for i in range(len(results[year])):
        try:
            country_count[results[year][i]['sourcecountry']] +=1
        except:
            country_count[results[year][i]['sourcecountry']] =1

    country_count = sorted(country_count.items(), reverse=True, key=lambda item: item[1])
    df = pd.DataFrame.from_dict(country_count).set_axis(['Country', 'Count'], axis=1)
    df['Year'] = year
    country_df= pd.concat([country_df,df])

country_df.index +=1

# %% [markdown]
# ### All languages for NATO (With extra queries)

# %%
#Input fixed parameters
parameters = {
"query": '"belt and road"OR"one belt one road"OR"la Ceinture et la Route"OR"Nuova via della seta"OR"Seidenstraßen"%20(sourcecountry:FR%20OR%20sourcecountry:GM%20OR%20sourcecountry:IT%20OR%20sourcecountry:US%20OR%20sourcecountry:UK)',
"startdatetime": '',
"enddatetime": '',
"format": "JSON",
"maxrecords": 250,
"sort": "DateDesc",
"mode": "ToneChart"}

# %%
import urllib.parse

nato_countries_cut = ['FR','GM','IT','US','GB','SW','DA','TU','SP','PL']


for year in range(2017,2024):
    results[str(year)] = []
    

    #Range Array for parameters
    r = pd.date_range(str(year)+'0101',str(year)+'1231')
    r = r.format(formatter=lambda x: x.strftime('%Y%m%d'))

    

    #Input parameters according to dates
    for day in tqdm(range(len(r))):
        time.sleep(5.5)
        parameters["startdatetime"] = r[day] + '000000'
        parameters["enddatetime"] = r[day] + '235959'
        
        #parameters["query"] = '"belt and road"+"one belt one road" (sourcecountry:%s)' %' OR sourcecountry:'.join(nato_countries_cut)#Query to search
        url = "https://api.gdeltproject.org/api/v2/doc/doc/?" + urllib.parse.urlencode(parameters, safe='():+')
        response = requests.get(url)
        
        #Prevent JSON escape errors
        output = fix_JSON(response.content.decode('utf8'))
        if len(output)!=0:
            for length in range(len(output['tonechart'])):
                if len(output['tonechart'][length]['toparts']) !=0:
                    for num_of_articles in range(len(output['tonechart'][length]['toparts'])):
                        details = {"title": output['tonechart'][length]['toparts'][num_of_articles]['title'],
                                    "url": output['tonechart'][length]['toparts'][num_of_articles]['url'],
                                    "date": r[day],
                                    "tone": output['tonechart'][length]['bin']}
                        results[str(year)].append(details)
# Out:
# 100%|██████████| 365/365 [46:49<00:00,  7.70s/it]
# 100%|██████████| 365/365 [46:46<00:00,  7.69s/it]
# 100%|██████████| 365/365 [46:49<00:00,  7.70s/it]
# 100%|██████████| 366/366 [46:56<00:00,  7.69s/it]
# 100%|██████████| 365/365 [46:35<00:00,  7.66s/it]
# 100%|██████████| 365/365 [45:56<00:00,  7.55s/it]
#  67%|██████▋   | 245/365 [30:30<14:56,  7.47s/it]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#       5     try:
# ----> 6         result = json.loads(json_message)
#       7     except Exception as e:
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 26)
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-99687c7ebcd4> in <module>
#      25
#      26         #Prevent JSON escape errors
# ---> 27         output = fix_JSON(response.content.decode('utf8'))
#      28         if len(output)!=0:
#      29             for length in range(len(output['tonechart'])):
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
# ---> 14         return fix_JSON(json_message=new_message)
#      15     return result
#
# <ipython-input-19-1197695a2873> in fix_JSON(json_message)
#      10         # Remove the offending character:
#      11         json_message = list(json_message)
# ---> 12         json_message[idx_to_replace] = ' '
#      13         new_message = ''.join(json_message)
#      14         return fix_JSON(json_message=new_message)
#
# IndexError: list assignment index out of range

# %%
unlabelled_domains = []
with open('labelled_domains.json') as f:
        labelled_domains = json.load(f)
unlabelled_count = 0

parameters = {
    "query": 'domain:global.chinadaily.com.cn',
    "format": "JSON",
    "maxrecords": 1,
    "mode": "ArtList"
}

# %%
year=2023
year = str(year)
for num in (range(0,len(results[year]))):
    #Get URL domain
    domain = str(urlparse(results[year][num]['url']).netloc)
    domain = re.sub(r'www.', '', domain)

    results[year][num]['domain'] = domain

    #Check domain with unlabelled domains first (Smaller dataset)
    if domain in unlabelled_domains:
        unlabelled_count+=1

    #Check domain with local data
    elif domain in labelled_domains:
        results[year][num]['sourcecountry'] = labelled_domains[domain]

    else:
        #Get sourcecountry from API
        parameters['query'] = 'domain:'+ domain
        response = requests.get("https://api.gdeltproject.org/api/v2/doc/doc", params=parameters)
        output = fix_JSON(response.content.decode('utf8'))
        if len(output) !=0:
            results[year][num]['sourcecountry'] = output['articles'][0]['sourcecountry']
            labelled_domains[domain] = output['articles'][0]['sourcecountry']
        else:
            unlabelled_domains.append(domain)
            unlabelled_count+=1

# %%
results['2022']
# Out:
# [{'title': 'Severe weather dangers mark 1st days of 2022',
#   'url': 'http://www.msn.com/en-us/weather/topstories/severe-weather-dangers-mark-1st-days-of-2022/vi-AAS1Kg1',
#   'date': '20220101',
#   'tone': -25,
#   'domain': 'msn.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Omicidio a Napoli | ucciso boss del clan Iadonisi | è la faida di Fuorigrotta con il clan Troncone',
#   'url': 'https://www.zazoom.it/2022-01-01/omicidio-a-napoli-ucciso-boss-del-clan-iadonisi-e-la-faida-di-fuorigrotta-con-il-clan-troncone/10100487/',
#   'date': '20220101',
#   'tone': -24,
#   'domain': 'zazoom.it',
#   'sourcecountry': 'Italy'},
#  {'title': 'Omicron New Year cocktail : Sorrow , fear , hope for 2022',
#   'url': 'https://www.pressenterpriseonline.com/apnews/omicrons-new-years-cocktail-sorrow-fear-hope-for-2022',
#   'date': '20220101',
#   'tone': -24,
#   'domain': 'pressenterpriseonline.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Severe weather on New Year Eve 2021 in Georgia',
#   'url': 'https://www.11alive.com/article/weather/severe-weather/severe-weather-georgia-december-31-2021/85-13506594-3fbd-493f-850c-3bb1c34ee560',
#   'date': '20220101',
#   'tone': -22,
#   'domain': '11alive.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Waterbuy man charged with murder of Georgia man',
#   'url': 'https://www.fox61.com/article/news/local/new-haven-county/waterbury/waterbury-murder-georgia-fight-arrest-investigation/520-1586d488-47b9-4732-8bdb-4df3d55d7adb',
#   'date': '20220101',
#   'tone': -22,
#   'domain': 'fox61.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Berwick man pleads guilty in one case ; awaits trial in others',
#   'url': 'https://www.pressenterpriseonline.com/daily/010122/page/3/story/berwick-man-pleads-guilty-in-one-case-awaits-trial-in-others',
#   'date': '20220101',
#   'tone': -21,
#   'domain': 'pressenterpriseonline.com',
#   'sourcecountry': 'United States'},
#  {'title': 'సంగారెడ్డి జిల్లాలో ఘోర రోడ్డు ప్రమాదం',
#   'url': 'https://www.andhrajyothy.com/telugunews/road-accident-in-sangareddy-district-vvr-mrgs-telangana-1922010103382043',
#   'date': '20220101',
#   'tone': -21,
#   'domain': 'andhrajyothy.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Coronavirus , in provincia di Caltanissetta altri 278 casi : deceduti due pazienti',
#   'url': 'https://www.seguonews.it/coronavirus-in-provincia-di-caltanissetta-altri-278-casi-deceduti-due-pazienti',
#   'date': '20220101',
#   'tone': -20,
#   'domain': 'seguonews.it',
#   'sourcecountry': 'Italy'},
#  {'title': 'Pierce deputies search for deadly shooting suspect in Spanaway',
#   'url': 'https://www.king5.com/article/news/crime/shooting-deadly-pierce-county-spanaway/281-bb9ab357-3ca4-4fa4-8472-888ba0947ae2',
#   'date': '20220101',
#   'tone': -20,
#   'domain': 'king5.com',
#   'sourcecountry': 'United States'},
#  {'title': 'AROUND THE STATE',
#   'url': 'https://www.pressenterpriseonline.com/daily/010122/page/2/story/around-the-state',
#   'date': '20220101',
#   'tone': -20,
#   'domain': 'pressenterpriseonline.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Namibia Press Agency',
#   'url': 'https://www.nampa.org/index.php?model=categories&function=display&id=21732032',
#   'date': '20220101',
#   'tone': -20,
#   'domain': 'nampa.org',
#   'sourcecountry': 'United States'},
#  {'title': '  Dark cloud  over communities after crash deaths',
#   'url': 'https://www.onenewspage.com/n/UK/1zo9wzjlz3/Dark-cloud-over-communities-after-crash-deaths-of.htm',
#   'date': '20220101',
#   'tone': -20,
#   'domain': 'onenewspage.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Man from Shasta County arrested for Sacramento homicide',
#   'url': 'https://www.abc10.com/article/news/local/sacramento/shasta-county-man-arrested-for-sac-homicide/103-c4a6e2b2-79b0-4fc2-a8a0-3edbecf2c768',
#   'date': '20220101',
#   'tone': -20,
#   'domain': 'abc10.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Man shot after attacking two Texas officers with knife on NYE',
#   'url': 'https://www.kiiitv.com/article/news/local/man-shot-after-assaulting-injuring-two-ccpd-officers-with-a-knife-on-new-years-eve/503-8a47bbdd-5d2a-4cce-ae5c-92975a89f5ec',
#   'date': '20220101',
#   'tone': -20,
#   'domain': 'kiiitv.com',
#   'sourcecountry': 'United States'},
#  {'title': 'LoDo shooting : Two killed , two injured on New Year Eve night',
#   'url': 'https://www.9news.com/article/news/local/two-killed-two-injured-overnight-shooting-denver/73-436fb717-dbe9-43f2-b907-1a211e1789e1',
#   'date': '20220101',
#   'tone': -20,
#   'domain': '9news.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Morte Calissano | Barbara DUrso sotto accusa per il tweet di cordoglio',
#   'url': 'https://www.zazoom.it/2022-01-01/morte-calissano-barbara-durso-sotto-accusa-per-il-tweet-di-cordoglio/10098030/',
#   'date': '20220101',
#   'tone': -19,
#   'domain': 'zazoom.it',
#   'sourcecountry': 'Italy'},
#  {'title': 'Marshall Fire : The latest on homes destroyed , acres burned',
#   'url': 'https://www.wbir.com/article/news/local/wildfire/multiple-grass-fires-boulder-county/73-d98c59a1-480e-47cc-b2b3-8a82baca0a58',
#   'date': '20220101',
#   'tone': -19,
#   'domain': 'wbir.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Dane Co . deputy allegedly hit in the face by suspect during arrest',
#   'url': 'https://www.wglr.com/2022/01/01/dane-co-deputy-allegedly-hit-in-the-face-by-suspect-during-arrest/',
#   'date': '20220101',
#   'tone': -19,
#   'domain': 'wglr.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Brighton Man Arrested for Second Felony Probation Violation',
#   'url': 'https://www.kciiradio.com/2022/01/01/brighton-man-arrested-for-second-felony-probation-violation/',
#   'date': '20220101',
#   'tone': -19,
#   'domain': 'kciiradio.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Tag : Mall of America – NBC Los Angeles',
#   'url': 'https://www.nbclosangeles.com/tag/mall-of-america/',
#   'date': '20220101',
#   'tone': -19,
#   'domain': 'nbclosangeles.com',
#   'sourcecountry': 'United States'},
#  {'title': 'Sunrise at the beach',
#   'url': 'https://www.carolinacoastonline.com/image_eb22664c-6b13-11ec-952d-5f59744ac2f8.html',
#   'date': '20220101',
#   'tone': -19,
#   'domain': 'carolinacoastonline.com',
#   'sourcecountry': 'United States'},
#  {'title': '
fr',
#   'sourcecountry': 'France'},
#  {'title': 'Rwanda : que reproche - t - on aux six étudiants condamnés à cinq ans de prison ? ',
#   'url': 'https://www.afrik.com/rwanda-que-reproche-t-on-aux-six-etudiants-condamnes-a-cinq-ans-de-prison',
#   'date': '20220101',
#   'tone': -6,
#   'domain': 'afrik.com',
#   'sourcecountry': 'Morocco'},
#  {'title': 'Birmanie : le rapport de force peut - il sinverser en faveur des opposants à la junte ? ',
#   'url': 'https://www.rfi.fr/fr/podcasts/le-monde-en-questions/20211231-birmanie-le-rapport-de-force-peut-il-s-inverser-en-faveur-des-opposants-%C3%A0-la-junte',
#   'date': '20220101',
#   'tone': -5,
#   'domain': 'rfi.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Saint - Gilles - Croix - de - Vie . Une fuite de gaz gâche le réveillon de 70\xa0personnes',
#   'url': 'https://larochesuryon.maville.com/actu/actudet_-saint-gilles-croix-de-vie.-une-fuite-de-gaz-gache-le-reveillon-de-70-personnes-_fil-5012093_actu.Htm',
#   'date': '20220101',
#   'tone': -5,
#   'domain': 'larochesuryon.maville.com'},
#  {'title': 'Tunisie : arrestation de lun des hommes forts dEnnahdha',
#   'url': 'https://www.lepoint.fr/monde/tunisie-arrestation-de-l-un-des-hommes-forts-d-ennahdha-01-01-2022-2458771_24.php',
#   'date': '20220101',
#   'tone': -5,
#   'domain': 'lepoint.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Rare capture dun léopard dans une région montagneuse dIrak',
#   'url': 'https://www.bfmtv.com/animaux/rare-capture-d-un-leopard-dans-une-region-montagneuse-d-irak_AD-202112310370.html',
#   'date': '20220101',
#   'tone': -5,
#   'domain': 'bfmtv.com',
#   'sourcecountry': 'France'},
#  {'title': 'Glissements de terrain en Afghanistan : au mois 350 personnes tuées',
#   'url': 'https://toulouse7.com/2014/05/03/glissements-de-terrain-en-afghanistan-au-mois-350-personnes-tuees/',
#   'date': '20220101',
#   'tone': -5,
#   'domain': 'toulouse7.com',
#   'sourcecountry': 'France'},
#  {'title': 'Omicron joue les trouble - fête pour l  économie américaine',
#   'url': 'https://www.challenges.fr/economie/omicron-joue-les-trouble-fete-pour-l-economie-americaine_794958',
#   'date': '20220101',
#   'tone': -5,
#   'domain': 'challenges.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Corée du Nord : Kim Jong Un fait de l  économie la priorité pour 2022',
#   'url': 'https://www.lexpress.fr/actualites/1/monde/coree-du-nord-kim-jong-un-fait-de-l-economie-la-priorite-pour-2022_2165289.html',
#   'date': '20220101',
#   'tone': -5,
#   'domain': 'lexpress.fr',
#   'sourcecountry': 'France'},
#  {'title': 'NHL postpones nine more games , 90 in all , for virus issues',
# ...
#  {'title': 'Covid - 19 en Israël : une quatrième dose de vaccin pour les plus de 60 ans et le personnel médical',
#   'url': 'https://www.lopinion.fr/international/covid-19-en-israel-une-quatrieme-dose-de-vaccin-pour-les-plus-de-60-ans-et-le-personnel-medical',
#   'date': '20220103',
#   'tone': -1,
#   'domain': 'lopinion.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Covid - 19 : le nouveau protocole disolement va nous mettre  en grande difficulté , craint lOrdre des pharmaciens',
#   'url': 'https://www.francetvinfo.fr/sante/maladie/coronavirus/covid-19-le-nouveau-protocole-d-isolement-va-nous-mettre-en-grande-difficulte-craint-lordre-des-pharmaciens_4902571.html',
#   'date': '20220103',
#   'tone': -1,
#   'domain': 'francetvinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Jean - Luc Mélenchon vexé par linstallation du drapeau européen sous lArc de Triomphe',
#   'url': 'https://lapauseinfo.fr/france-drapeau-europeen-arc-triomphe-melenchon-scandalise/',
#   'date': '20220103',
#   'tone': -1,
#   'domain': 'lapauseinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Rhône : une mère de famille au RSA récupérait des identifiants Doctolib pour vendre de faux pass sanitaires',
#   'url': 'https://www.ladepeche.fr/2022/01/03/rhone-une-mere-de-famille-au-rsa-recuperait-des-identifiants-doctolib-pour-vendre-de-faux-pass-sanitaires-10024408.php',
#   'date': '20220103',
#   'tone': -1,
#   'domain': 'ladepeche.fr',
#   'sourcecountry': 'France'},
#  {'title': 'La revue de presse des nouvelles restrictions Omicron du jour',
#   'url': 'https://www.lopinion.fr/politique/la-revue-de-presse-des-nouvelles-restrictions-omicron-du-jour',
#   'date': '20220103',
#   'tone': -1,
#   'domain': 'lopinion.fr',
#   'sourcecountry': 'France'},
#  {'title': '  Un seul vœu pour 2022 : vaccinez - vous !, appellent 500 médecins marseillais',
#   'url': 'https://www.nicematin.com/sante/un-seul-voeu-pour-2022-vaccinez-vous-appellent-500-medecins-marseillais-737104',
#   'date': '20220103',
#   'tone': -1,
#   'domain': 'nicematin.com',
#   'sourcecountry': 'France'},
#  {'title': 'Gabon – Burkina : les Panthères se seraient fait écraser ( 0 - 3 ) pour une affaire de primes - ',
#   'url': 'https://gabonactu.com/gabon-burkina-les-pantheres-se-seraient-fait-ecraser-0-3-pour-une-affaire-de-primes/',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'gabonactu.com',
#   'sourcecountry': 'Gabon'},
#  {'title': 'Nécrologie : Jean Marc Ekoh est mort - ',
#   'url': 'https://gabonactu.com/necrologie-jean-marc-ekoh-est-mort/',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'gabonactu.com',
#   'sourcecountry': 'Gabon'},
#  {'title': 'Covid - 19 à l  école : communication par la presse , journées hybrides ... pourquoi le protocole de Jean - Michel Blanquer fait polémique',
#   'url': 'https://www.ladepeche.fr/2022/01/03/covid-19-a-lecole-communication-par-la-presse-journees-hybrides-pourquoi-le-protocole-de-jean-michel-blanquer-fait-polemique-10024302.php',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'ladepeche.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Linvestisseur Peter Thiel recrute lex - chancelier autrichien Sebastian Kurz',
#   'url': 'https://www.lefigaro.fr/societes/l-investisseur-peter-thiel-recrute-l-ex-chancelier-autrichien-sebastian-kurz-20220102',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'lefigaro.fr',
#   'sourcecountry': 'France'},
#  {'title': 'A Marseille , lappel de 500 médecins :  Un seul vœu pour 2022 : vaccinez - vous ! ',
#   'url': 'https://www.francetvinfo.fr/sante/maladie/coronavirus/vaccin/un-seul-voeu-pour-2022-vaccinez-vous-appellent-500-medecins-marseillais_4902589.html',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'francetvinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': ' # COVID _ 19 Bonjour ! Pendant tout le début de l  épidémie',
#   'url': 'https://www.francetvinfo.fr/live/message/61d/2b2/6e5/ff4/e94/7b2/912/f85.html',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'francetvinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Retraites : revalorisations , services en ligne ... ce qui évolue en 2022',
#   'url': 'https://www.ladepeche.fr/2022/01/03/retraites-revalorisations-services-en-ligne-ce-qui-evolue-en-2022-10024288.php',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'ladepeche.fr',
#   'sourcecountry': 'France'},
#  {'title': ' # COVID _ 19 De nombreuses mesures annoncées ces derniers',
#   'url': 'https://www.francetvinfo.fr/live/message/61d/2b4/5c8/256/bf9/7cd/812/62e.html',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'francetvinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Les dates des soldes dhiver 2022 sont connues',
#   'url': 'https://www.ladepeche.fr/2022/01/03/les-dates-des-soldes-dhiver-2022-sont-connues-10024334.php',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'ladepeche.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Les travaux du parc de la Mauvotte vont commencer',
#   'url': 'https://www.lyonne.fr/soucy-89100/actualites/les-travaux-du-parc-de-la-mauvotte-vont-commencer_14068402/',
#   'date': '20220103',
#   'tone': 0,
#   'domain': 'lyonne.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Au Soudan , le Premier ministre , Abdallah Hamdok , a',
#   'url': 'https://www.francetvinfo.fr/live/message/61d/2b5/e45/ff4/e94/7b2/912/f8e.html',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'francetvinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': 'The Green Knight avec Dev Patel sur Prime Video : que vaut ce conte de fantasy , tiré dune légende arthurienne ? - Actus Ciné',
#   'url': 'https://www.allocine.fr/article/fichearticle_gen_carticle=18705579.html',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'allocine.fr',
#   'sourcecountry': 'France'},
#  {'title': ' # COVID _ 19 Bonjour @ Lou ! Absolument',
#   'url': 'https://www.francetvinfo.fr/live/message/61d/2a5/c68/256/bf9/7c7/812/60f.html',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'francetvinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Mittersheim . Peintre d  églises à 71 ans\xa0 : la ferveur de Nicole Kling pour son métier',
#   'url': 'https://www.republicain-lorrain.fr/culture-loisirs/2022/01/03/peintre-d-eglises-a-71-ans-la-ferveur-de-nicole-kling-pour-son-metier',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'republicain-lorrain.fr'},
#  {'title': 'Foires , salons , parcs dattractions et zoos échappent au retour des jauges le 3 janvier',
#   'url': 'https://www.le-pays.fr/paris-75000/actualites/foires-salons-parcs-d-attractions-et-zoos-echappent-au-retour-des-jauges-le-3-janvier_14067641/',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'le-pays.fr'},
#  {'title': ' # COVID _ 19 Lannonce de la gratuité des autotests pour les',
#   'url': 'https://www.francetvinfo.fr/live/message/61d/2b6/705/ff4/e94/7a6/912/f76.html',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'francetvinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Le château ne manque pas de projets - La Motte - Tilly ( 10400 ) ',
#   'url': 'https://www.lyonne.fr/motte-tilly-10400/actualites/le-chateau-ne-manque-pas-de-projets_14068404/',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'lyonne.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Les douze derniers mois ont été marqués par des chiffres qui feront date',
#   'url': 'https://www.le-pays.fr/paris-75000/actualites/les-douze-derniers-mois-ont-ete-marques-par-des-chiffres-qui-feront-date_14067058/',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'le-pays.fr'},
#  {'title': 'Cyril Hanouna : pourquoi son nouveau film fait polémique ? ',
#   'url': 'https://www.femmeactuelle.fr:443/actu/news-actu/cyril-hanouna-pourquoi-son-nouveau-film-fait-polemique-2126109',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'femmeactuelle.fr:443'},
#  {'title': 'Elsa Fayer :  Je ne suis jamais partie de chez moi sans pleurer avant un tournage  - INTERVIEW : Femme Actuelle Le MAG',
#   'url': 'https://www.femmeactuelle.fr:443/actu/news-actu/elsa-fayer-je-ne-suis-jamais-partie-de-chez-moi-sans-pleurer-avant-un-tournage-interview-2126108',
#   'date': '20220103',
#   'tone': 1,
#   'domain': 'femmeactuelle.fr:443'},
#  {'title': '2022\xa0 : une année de la grande mobilisation pour le CLR - ',
#   'url': 'https://gabonactu.com/2022-une-annee-de-la-grande-mobilisation-pour-le-clr/',
#   'date': '20220103',
#   'tone': 2,
#   'domain': 'gabonactu.com',
#   'sourcecountry': 'Gabon'},
#  {'title': 'Rodolphe Belmer prend ses fonctions de Directeur Général dAtos',
#   'url': 'https://www.silicon.fr/press-release/rodolphe-belmer-prend-ses-fonctions-de-directeur-gnral-datos',
#   'date': '20220103',
#   'tone': 2,
#   'domain': 'silicon.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Bella Hadid , promenade en amoureux avec Marc Kalman',
#   'url': 'https://www.parismatch.com/People/Bella-Hadid-promenade-en-amoureux-avec-Marc-Kalman-1779211',
#   'date': '20220103',
#   'tone': 2,
#   'domain': 'parismatch.com',
#   'sourcecountry': 'France'},
#  {'title': 'Quand il nest pas subi , le travail à domicile améliorerait la productivité des entreprises',
#   'url': 'https://www.lefigaro.fr/conjoncture/quand-il-n-est-pas-subi-le-travail-a-domicile-ameliorerait-la-productivite-des-entreprises-20220102',
#   'date': '20220103',
#   'tone': 2,
#   'domain': 'lefigaro.fr',
#   'sourcecountry': 'France'},
#  {'title': '  Nous avons besoin de respiration et de liberté',
#   'url': 'https://www.francetvinfo.fr/live/message/61d/
fr',
#   'sourcecountry': 'France'},
#  {'title': 'Linflation senflamme en Turquie',
#   'url': 'https://www.francetvinfo.fr/live/message/61d/2ab/1e8/256/bf9/7c4/812/62d.html',
#   'date': '20220103',
#   'tone': 4,
#   'domain': 'francetvinfo.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Promos voitures neuves\xa0 : ce seront les bonnes\xa0affaires de 2022',
#   'url': 'https://www.caradisiac.com/promos-voitures-neuves-les-meilleures-affaires-de-2022-193895.htm',
#   'date': '20220103',
#   'tone': 4,
#   'domain': 'caradisiac.com',
#   'sourcecountry': 'France'},
#  {'title': 'Croissance interne : définition , formes et leviers',
#   'url': 'https://www.capital.fr/economie-politique/croissance-interne-definition-formes-et-leviers-1423629',
#   'date': '20220103',
#   'tone': 4,
#   'domain': 'capital.fr',
#   'sourcecountry': 'France'},
#  {'title': '75 ans de mariage : Le Port : noces dalbâtre pour les époux Boitard',
#   'url': 'https://www.ipreunion.com/le-port-actualite/reportage/2022/01/03/75-ans-de-mariage-le-port-noces-d-albatre-pour-les-epoux-boitard,145467.html',
#   'date': '20220103',
#   'tone': 4,
#   'domain': 'ipreunion.com'},
#  {'title': 'Céréales , tartines ... Que manger pour un petit déjeuner équilibré et savoureux ? ',
#   'url': 'https://www.rtl.fr/actu/food/cereales-tartines-que-manger-pour-un-petit-dejeuner-equilibre-et-savoureux-7900098519',
#   'date': '20220103',
#   'tone': 4,
#   'domain': 'rtl.fr',
#   'sourcecountry': 'France'},
#  {'title': 'Diapos et cassettes : importante découverte archéologique dans un collège',
#   'url': 'https://www.nouvelobs.com/chroniques/20220103.OBS52795/diapos-et-cassettes-importante-decouverte-archeologique-dans-un-college.html',
#   'date': '20220103',
#   'tone': 4,
#   'domain': 'nouvelobs.com',
#   'sourcecountry': 'France'},
#  {'title': 'Horoscope 2022 . Poissons : les célibataires trouveront la perle rare',
#   'url': 'https://www.ledauphine.com/societe/2022/01/03/poissons-les-celibataires-trouveront-la-perle-rare',
#   'date': '20220103',
#   'tone': 4,
#   'domain': 'ledauphine.com',
#   'sourcecountry': 'France'},
#  {'title': 'Jane Birkin - La biographie de Jane Birkin avec Voici . fr',
#   'url': 'https://www.voici.fr/bios-people/jane-birkin',
#   'date': '20220103',
#   'tone': 4,
#   'domain': 'voici.fr',
#   'sourcecountry': 'France'},
#  ...]

# %%
range(len(results[year]))
# Out:
# range(0, 154812)

# %% [markdown]
# ## Data pre-processing

# %%
with open('./Final Data/2 - sourcecountry.json') as f:
        results = json.load(f)

# %%
with open('unlabelled_domains.json') as f:
        unlabelled_domains = json.load(f)

# %% [markdown]
# #### Remove duplicates and also low-quality news articles with same titles

# %%
#Edited from Remove duplicate from list of dict based on key value by Jean-François Fabre
#https://stackoverflow.com/questions/43319409/remove-duplicates-key-from-list-of-dictionaries-python
def remove_duplicate(list_of_dict):
    done = set()
    result = []
    for d in list_of_dict:
        phrase = " ".join(d['title'].split()[:5]).lower()
        if phrase not in done:
            done.add(phrase)  # note it down for further iterations
            result.append(d)
    return result

# %%
results_removed_duplicates = {}
for year in range(2017,2024):
    print(str(year)+" Number of articles before: " + str(len(results[str(year)])))
    results_removed_duplicates[str(year)] = remove_duplicate(results[str(year)])
    print(str(year)+" Number of articles after: " + str(len(results_removed_duplicates[str(year)])))

print("\nNumber of duplicated news articles removed: ", sum(len(results[year]) for year in results)-
                                            sum(len(results_removed_duplicates[year]) for year in results_removed_duplicates))
                                        
print("Number of news articles before pre-processing: ", sum(len(results[year]) for year in results))

print("Number of news articles after pre-processing: ", sum(len(results_removed_duplicates[year]) for year in results_removed_duplicates))
# Out:
# 2017 Number of articles before: 33683
# 2017 Number of articles after: 18890
# 2018 Number of articles before: 35333
# 2018 Number of articles after: 19506
# 2019 Number of articles before: 34471
# 2019 Number of articles after: 19160
# 2020 Number of articles before: 24081
# 2020 Number of articles after: 12922
# 2021 Number of articles before: 27435
# 2021 Number of articles after: 12973
# 2022 Number of articles before: 27183
# 2022 Number of articles after: 11686
# 2023 Number of articles before: 15147
# 2023 Number of articles after: 7415
#
# Number of duplicated news articles removed:  94781
# Number of news articles before pre-processing:  197333
# Number of news articles after pre-processing:  102552

# %%
unlabelled_domains_count = {}
labelled_domains_count = {}
for year in range(2017,2024):
    year = str(year)
    for num in range(len(results[year])):
        if results[year][num]['domain'] in unlabelled_domains:
            try:
                unlabelled_domains_count[results[year][num]['domain']] +=1
            except:
                unlabelled_domains_count[results[year][num]['domain']] = 1
        try:
            if results[year][num]['sourcecountry'] == "":
                try:
                    unlabelled_domains_count[results[year][num]['domain']] +=1
                except:
                    unlabelled_domains_count[results[year][num]['domain']] = 1
            else:
                try:
                    labelled_domains_count[results[year][num]['domain']] +=1
                except:
                    labelled_domains_count[results[year][num]['domain']] = 1
        except:
            pass

# %% [markdown]
# #### Sort and convert list to list of dict

# %%
unlabelled_domains_count = dict(sorted(unlabelled_domains_count.items(), reverse=True, key=lambda item: item[1]))

# %%
unlabelled_domain_dict = [] #Dict for manually labelling domains with 50 or more news articles
for num in range(len(unlabelled_domains_count)):
    details = {'domain': list(unlabelled_domains_count.keys())[num],
                'count': unlabelled_domains_count.get(list(unlabelled_domains_count.keys())[num])}
    unlabelled_domain_dict.append(details)

# %%
more_articles = more_count = less_articles = less_count = 0
for num in range(len(unlabelled_domain_dict)):
    if unlabelled_domain_dict[num]['count'] < 50:
        less_articles+= unlabelled_domain_dict[num]['count']
        less_count+= 1
    else:
        more_articles+= unlabelled_domain_dict[num]['count']
        more_count+=1
print(str(less_count) + ' domains with less than 50 news articles: ' + str(less_articles))
print(str(more_count) + ' domains with 50 or more news articles: ' + str(more_articles))
# Out:
# 2208 domains with less than 50 news articles: 8967
# 62 domains with 50 or more news articles: 12689

# %% [markdown]
# As manual labelling is time intensive, labelling domains with 50 or more news articles will cover more than half of the unlabelled dataset

# %% [markdown]
# #### Domains that are deemed to be invalid
# - Domains that consists of reposts of other news articles
# - Domains that consistently consists of news articles not relevant to BRI
# - Wordpress/Blogs that are not media outlets
# - Domains that consists of less than 50 news articles

# %%
#Combine manually deemed invalid domains with news articles less than 50
removed_domains = []
removed_domains.extend(manually_removed_domains)
for i in range(0,len(unlabelled_domain_dict)):
    try:
        unlabelled_domain_dict[i]['sourcecountry']
    except:
        if unlabelled_domain_dict[i]['domain'] not in manually_removed_domains:
            removed_domains.append(unlabelled_domain_dict[i]['domain'])

print('Total domains removed: ', len(removed_domains))
# Out:
# Total domains removed:  2224

# %% [markdown]
# #### Remove invalid domains based on 'removed_domains' and label respective 'sourcecountry'

# %%
results_removed_domains = {}

for year in range(2017,2024):
    year = str(year)
    results_removed_domains[year] = []
    for i in range(len(results[year])):
        if results[year][i]['domain'] not in removed_domains:
            try:
                if results[year][i]['sourcecountry'] == "":
                    results[year][i]['sourcecountry'] = next(item['sourcecountry'] for item in unlabelled_domain_dict if item["domain"] == results[year][i]['domain'])
            except:
                try:
                    results[year][i]['sourcecountry'] = next(item['sourcecountry'] for item in unlabelled_domain_dict if item["domain"] == results[year][i]['domain'])
                except:
                    print(year,i)
            results_removed_domains[year].append(results[year][i])



print("Number of news articles removed: ", sum(len(results[year]) for year in results)-sum(len(results_removed_domains[year]) for year in results_removed_domains))
# Out:
# Number of news articles removed:  11618

# %%
with open('labelled_domains.json') as f:
        labelled_domains = json.load(f)

for i in range(len(unlabelled_domain_dict)):
    try:
        labelled_domains[unlabelled_domain_dict[i]['domain']] = unlabelled_domain_dict[i]['sourcecountry']
    except:
        pass

#with open('labelled_domains.json', 'w', encoding='utf-8') as f:
        #json.dump(labelled_domains, f, indent=4, default=str)

# %%
#with open('./Final Data/3 - final_data.json', 'w', encoding='utf-8') as f:
        #json.dump(results_removed_domains, f, indent=4, default=str)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Run from here for data exploration using saved files

# %%
import pandas as pd
import json
import plotly.express as px
import plotly.graph_objects as go
import country_converter as coco

with open('./Final Data/3 - final_data.json') as f:
        final_results = json.load(f)

# %% [markdown]
# ### Visualise number of articles in each country over the years

# %%
country_df = pd.DataFrame(columns=['Country','Count','Year'])
country_df["Count"]=country_df["Count"].astype(float)
for year in range(2017,2024):
    country_count = {}
    year = str(year)
    for i in range(len(final_results[year])):
        try:
            country_count[final_results[year][i]['sourcecountry']] +=1
        except:
            country_count[final_results[year][i]['sourcecountry']] =1

    country_count = sorted(country_count.items(), reverse=True, key=lambda item: item[1])
    df = pd.DataFrame.from_dict(country_count).set_axis(['Country', 'Count'], axis=1)
    df['Year'] = year
    country_df= pd.concat([country_df,df])

country_df.index +=1

# %%
#Discrete colours according to range
bins = [0, 10, 50, 500, 1000, 2500, 4000, 10000]
labels = [f"{i}-{j}" for i, j in zip(bins[:-1], bins[1:])]
country_df["Count_range"] = pd.cut(country_df["Count"], bins=bins, labels=labels)

color_scale = {
    "0-10": '#0d0887',
    "10-50": '#46039f',
    "50-500": '#7201a8',
    "500-1000": '#9c179e',
    "1000-2500": '#bd3786',
    "2500-4000": '#d8576b',
    "4000-10000": '#ed7953',
}

fig = px.choropleth(country_df,
                    locations="Country",
                    color="Count_range",
                    hover_data={"Country": False,
                                "Count": True,
                                "Year": False,
                                "Count_range": False},
                    hover_name="Country", # column to add to hover information
                    locationmode="country names",
                    animation_frame="Year",
                    color_discrete_sequence= ['#ed7953','#d8576b','#bd3786','#9c179e','#7201a8','#46039f','#0d0887'],
                    category_orders={"Count_range": ["4000-10000", "2500-4000", "1000-2500", "500-1000", "50-500", "10-50", "0-10"]},
                    )

fig.update_layout(
    autosize=False,
    width=1200,
    height=800,)

fig.show()

# %% [markdown]
# ### Visualise average tone of each country over the years

# %% [markdown]
# #### Calculate average tone each year

# %%
country_df['Average Tone'] = 0
for year in range(2017,2024):
    year = str(year)
    total_tone = 0
    for num in range(len(final_results[year])):
        country = final_results[year][num]['sourcecountry']
        tone = final_results[year][num]['tone']
        country_df.loc[(country_df['Country']==country) & (country_df['Year']==str(year)), 'Average Tone'] += int(tone)

country_df["Average Tone"]=country_df["Average Tone"].astype(float)
for num in range(len(country_df)):
    country_df.iat[num,4] = country_df.iat[num,4] / country_df.iat[num,1]

# %%
#load csv
country_df = pd.read_csv('./csv/country_df.csv', index_col=0)

# %%
fig = px.choropleth(country_df,
                    locations="Country",
                    color="Average Tone",
                    hover_data={"Country": False,
                                "Count": True,
                                "Year": False,
                                "Count_range": False,
                                "Average Tone": True},
                    hover_name="Country", # column to add to hover information
                    locationmode="country names",
                    animation_frame="Year",
                    color_discrete_map=px.colors.sequential.Plasma
                    )

fig.update_layout(
    autosize=False,
    width=1200,
    height=800,)

fig.show()

# %% [markdown]
# ### Visualise average tone by region

# %% [markdown]
# #### Add ISO3 code and Region

# %%
# Read csv file
UNSD_region = pd.read_csv('UNSD — Methodology.csv', sep=';')

# %%
# create a dictionary that matches each country to its region
region_dict = dict(zip(UNSD_region['ISO-alpha3 Code'], UNSD_region['Region Name']))

# create a dictionary that matches each country to its sub-region
subregion_dict = dict(zip(UNSD_region['ISO-alpha3 Code'], UNSD_region['Sub-region Name']))

# add Taiwan to the region_dict dictionary
region_dict.update({'TWN': 'Asia'})

# add Taiwan to the subregion_dict dictionary
subregion_dict.update({'TWN': 'Eastern Asia'})

# %%
import country_converter as coco

results_df = pd.DataFrame()
for year in range(2017,2024):
    #Convert final_results['year'] to temp_df
    temp_df = pd.DataFrame(final_results[str(year)])
    temp_df['Year'] = year
    results_df = pd.concat([results_df, temp_df], axis=0)

#Add Alpha ISO3 code and region using UNSD data
results_df['ISO-alpha3 Code'] = ''
results_df['Region'] = ''
results_df['Sub-Region'] = ''

results_df.loc[(results_df['sourcecountry']=='Taiwan'), 'ISO-alpha3 Code'] = 'TWN'

for num in range(len(results_df)):
    results_df.iat[num,7] = coco.convert(names=results_df.iat[num,5], to='ISO3')
    results_df.iat[num,8] = region_dict[results_df.iat[num,7]]
    results_df.iat[num,9] = subregion_dict[results_df.iat[num,7]]

# %%
#load csv
import pandas as pd
results_df = pd.read_csv('./csv/results_df.csv', index_col=0)
# Out:
# /Users/le/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.2' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# #### Calculate average tone by region and sub-region

# %%
country_df['ISO3'] = ''
iso_dict = coco.convert(names=list(country_df['Country']), to='ISO3')
country_df['ISO3'] = iso_dict

# %%
country_df['Region'] = ''
country_df['Region'] = country_df['ISO3'].map(region_dict)
country_df['Sub-region'] = ''
country_df['Sub-region'] = country_df['ISO3'].map(subregion_dict)

# %%
region_df = pd.DataFrame(columns=['Region','Count', 'Year', 'Average Tone'])
region_list = ['Africa', 'Americas', 'Asia', 'Europe', 'Oceania']

subregion_df = pd.DataFrame(columns=['Sub-Region','Count', 'Year', 'Average Tone'])
subregion_list = ['Northern Africa', 'Sub-Saharan Africa',
                  'Latin America and the Caribbean', 'Northern America', 
                  'Central Asia', 'Eastern Asia', 'Southern Asia', 'South-eastern Asia', 'Western Asia', 
                  'Eastern Europe', 'Northern Europe', 'Southern Europe', 'Western Europe', 
                  'Australia and New Zealand', 'Melanesia', 'Micronesia', 'Polynesia']

region_temp_df = pd.DataFrame(columns=['Region','Count', 'Year', 'Average Tone'])
region_temp_df["Average Tone"]=region_temp_df["Average Tone"].astype(float)
region_temp_df["Count"]=region_temp_df["Count"].astype(float)
region_temp_df['Region'] = region_list

subregion_temp_df = pd.DataFrame(columns=['Sub-Region','Count', 'Year', 'Average Tone'])
subregion_temp_df["Average Tone"]=subregion_temp_df["Average Tone"].astype(float)
subregion_temp_df["Count"]=subregion_temp_df["Count"].astype(float)
subregion_temp_df['Sub-Region'] = subregion_list

for year in range(2017,2024):
    region_temp_df['Average Tone'] = region_temp_df["Count"] = 0
    region_temp_df['Year'] = year

    subregion_temp_df['Average Tone'] = subregion_temp_df["Count"] = 0
    subregion_temp_df['Year'] = year

    for num in range(len(country_df[country_df['Year']== year])):
        #By Region
        region = region_dict[country_df[country_df['Year']== year].iat[num,5]]
        tone = country_df[country_df['Year']== year].iat[num,4]
        region_temp_df.loc[(region_temp_df['Region']==region) & (region_temp_df['Year']==year), 'Average Tone'] += tone
        region_temp_df.loc[(region_temp_df['Region']==region) & (region_temp_df['Year']==year), 'Count'] += 1
        
        #By Sub-Region
        sub_region = subregion_dict[country_df[country_df['Year']== year].iat[num,5]]
        subregion_temp_df.loc[(subregion_temp_df['Sub-Region']==sub_region) & (subregion_temp_df['Year']==year), 'Average Tone'] += tone
        subregion_temp_df.loc[(subregion_temp_df['Sub-Region']==sub_region) & (subregion_temp_df['Year']==year), 'Count'] += 1

    region_df= pd.concat([region_df, region_temp_df])
    subregion_df= pd.concat([subregion_df, subregion_temp_df])

for num in range(len(region_df)):
    region_df.iat[num,3] = region_df.iat[num,3] / region_df.iat[num,1]

for num in range(len(subregion_df)):
    subregion_df.iat[num,3] = subregion_df.iat[num,3] / subregion_df.iat[num,1]
# Out:
# <ipython-input-18-175a51d24688>:47: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %%
subregion_df.insert(1,'Region','')
for num in range(len(subregion_df)):
    try:
        subregion_df.iat[num,1] = UNSD_region[UNSD_region['Sub-region Name']==subregion_df.iat[num,0]]['Region Name'].iat[0]
    except:
        print(subregion_df.iat[num,0])

# %%
fig = px.line(country_df, x="Year", y="Average Tone", color="Region", line_group="Country", hover_name="Country",
        line_shape="spline", render_mode="svg")

fig.update_layout(
    autosize=False,
    width=1200,
    height=1200,)
fig.show()

# %%
fig = px.line(country_df, x="Year", y="Average Tone", color="Sub-region", line_group="Country", hover_name="Country",
        line_shape="spline", render_mode="svg")

fig.update_layout(
    autosize=False,
    width=1200,
    height=1200,)
fig.show()

# %%
fig = px.line(region_df, x="Year", y="Average Tone", color="Region", line_group="Region", hover_name="Region",
        line_shape="spline", render_mode="svg", title='Average Tone by Region')

fig.update_layout(
    autosize=False,
    width=1200,
    height=500,)
fig.show()

# %%
fig = px.line(subregion_df, x="Year", y="Average Tone", color="Sub-Region", line_group="Sub-Region", hover_name="Sub-Region",
        line_shape="spline", render_mode="svg", title='Average Tone by Sub-Region')

fig.update_layout(
    autosize=False,
    width=1200,
    height=500,)
fig.show()

# %%
fig = px.histogram(country_df, x="Average Tone", animation_frame="Year", title = 'Histogram of average tone by Year')
fig.update_layout(
    autosize=False,
    width=1200,
    height=1000,)
fig.show()

# %% [markdown]
# ### Visualise by month

# %% [markdown]
# #### Create new dataframe that has average tone per month

# %%
# create an empty dictionary to hold the results
results = {}

# loop through the data and calculate the average tone for each country for each month-year combination
for year, data in final_results.items():
    for item in data:
        month_year = item['date'][:6] # extract the month-year from the date
        if month_year not in results:
            results[month_year] = {}
        country = item['sourcecountry']
        tone = item['tone']
        if country not in results[month_year]:
            results[month_year][country] = []
        results[month_year][country].append(tone)

# fill in the results dictionary with the calculated values
for month_year, country_data in results.items():
    for country, tone_list in country_data.items():
        avg_tone = sum(tone_list) / len(tone_list)
        results[month_year][country] = avg_tone

# create a dataframe from the results dictionary
country_month_df = pd.DataFrame.from_dict(results, orient='columns')

# %%
country_month_df
# Out:
#                                  ISO3    Region
# China                             CHN      Asia  \
# Japan                             JPN      Asia
# United Arab Emirates              ARE      Asia
# Pakistan                          PAK      Asia
# United States                     USA  Americas
# ...                               ...       ...
# Mozambique                        MOZ    Africa
# Swaziland                         SWZ    Africa
# Saint Vincent and the Grenadines  VCT  Americas
# British Virgin Islands            VGB  Americas
# Guatemala                         GTM  Americas
#
#                                                        Sub-region    201701
# China                                                Eastern Asia  1.365772  \
# Japan                                                Eastern Asia -0.375000
# United Arab Emirates                                 Western Asia  1.000000
# Pakistan                                            Southern Asia  1.416667
# United States                                    Northern America  0.725000
# ...                                                           ...       ...
# Mozambique                                     Sub-Saharan Africa       NaN
# Swaziland                                      Sub-Saharan Africa       NaN
# Saint Vincent and the Grenadines  Latin America and the Caribbean       NaN
# British Virgin Islands            Latin America and the Caribbean       NaN
# Guatemala                         Latin America and the Caribbean       NaN
#
#                                     201702    201703    201704    201705
# China                             1.071749  1.434368  0.362563  0.015584  \
# Japan                             0.000000  4.500000 -1.000000 -0.500000
# United Arab Emirates             -2.000000  3.500000  4.000000  0.000000
# Pakistan                          0.954545  1.885714  1.547619 -0.149254
# United States                     0.347826  0.277778  0.175439 -0.699187
# ...                                    ...       ...       ...       ...
# Mozambique                             NaN       NaN       NaN       NaN
# Swaziland                              NaN       NaN       NaN       NaN
# Saint Vincent and the Grenadines       NaN       NaN       NaN       NaN
# British Virgin Islands                 NaN       NaN       NaN       NaN
# Guatemala                              NaN       NaN       NaN       NaN
#
#                                     201706    201707  ...    202208    202209
# China                             1.330420  0.893305  ...  1.050157  1.863510  \
# Japan                            -1.800000  0.000000  ... -0.666667 -1.400000
# United Arab Emirates             -0.800000  1.166667  ...  6.000000  0.333333
# Pakistan                         -0.015873  0.166667  ... -0.333333 -0.589744
# United States                    -0.509934 -0.552448  ... -2.030303 -1.523560
# ...                                    ...       ...  ...       ...       ...
# Mozambique                             NaN       NaN  ...       NaN       NaN
# Swaziland                              NaN       NaN  ...       NaN       NaN
# Saint Vincent and the Grenadines       NaN       NaN  ...       NaN       NaN
# British Virgin Islands                 NaN       NaN  ...       NaN       NaN
# Guatemala                              NaN       NaN  ...       NaN       NaN
#
#                                     202210    202211    202212    202301
# China                             1.682779  1.829268  1.629032  1.416107  \
# Japan                            -0.444444  2.000000 -2.800000 -2.200000
# United Arab Emirates              2.750000  1.250000  1.857143       NaN
# Pakistan                         -0.181818  1.933333  0.636364  1.181818
# United States                    -1.392241 -0.851282 -1.047872 -1.782895
# ...                                    ...       ...       ...       ...
# Mozambique                             NaN       NaN       NaN       NaN
# Swaziland                              NaN       NaN       NaN       NaN
# Saint Vincent and the Grenadines       NaN       NaN       NaN       NaN
# British Virgin Islands                 NaN       NaN       NaN       NaN
# Guatemala                              NaN       NaN       NaN       NaN
#
#                                     202302    202303    202304    202305
# China                             1.509294  1.703927  1.675781  1.217391
# Japan                             2.500000 -2.000000 -3.333333       NaN
# United Arab Emirates              1.400000  2.571429  0.285714       NaN
# Pakistan                          0.031250  0.333333  0.781250 -0.500000
# United States                    -1.753012 -1.195000 -0.797546 -1.538462
# ...                                    ...       ...       ...       ...
# Mozambique                             NaN       NaN       NaN       NaN
# Swaziland                              NaN       NaN       NaN       NaN
# Saint Vincent and the Grenadines       NaN       NaN       NaN       NaN
# British Virgin Islands                 NaN       NaN       NaN       NaN
# Guatemala                              NaN       NaN       NaN       NaN
#
# [171 rows x 80 columns]

# %%
country_month_df.insert(loc=0, column='ISO3', value='')
iso_dict = coco.convert(names=list(country_month_df.index), to='ISO3')
country_month_df['ISO3'] = iso_dict

# %%
country_month_df.insert(loc=1, column='Region', value='')
country_month_df['Region'] = country_month_df['ISO3'].map(region_dict)
country_month_df.insert(loc=2, column='Sub-region', value='')
country_month_df['Sub-region'] = country_month_df['ISO3'].map(subregion_dict)

# %% [markdown]
# ### NATO Countries only

# %% [markdown]
# #### By Month-Year

# %%
# Define list of NATO member countries
nato_countries = ["ALB", "BEL", "BGR", "CAN", "HRV", "CZE", "DNK", "EST", "FIN", "FRA", "DEU", "GRC",
                  "HUN", "ISL", "ITA", "LVA", "LTU", "LUX", "MNE", "NLD", "MKD", "NOR", "POL", "PRT",
                  "ROU", "SVK", "SVN", "ESP", "TUR", "GBR", "USA"]

# Filter original DataFrame to only include NATO member countries
nato_month_df = country_month_df[country_month_df['ISO3'].isin(nato_countries)]

# Create new DataFrame with selected columns
nato_month_df = nato_month_df[['ISO3', 'Region', 'Sub-region'] + list(nato_month_df.columns[3:])]

# Display new DataFrame
nato_month_df = nato_month_df.sort_index()

nato_month_df
# Out:
#                 ISO3    Region        Sub-region  201701    201702    201703
# Albania          ALB    Europe   Southern Europe     NaN       NaN       NaN  \
# Belgium          BEL    Europe    Western Europe     NaN       NaN       NaN
# Bulgaria         BGR    Europe    Eastern Europe     NaN       NaN       NaN
# Canada           CAN  Americas  Northern America     NaN       NaN  0.000000
# Croatia          HRV    Europe   Southern Europe     NaN       NaN       NaN
# Czech Republic   CZE    Europe    Eastern Europe     NaN       NaN       NaN
# Denmark          DNK    Europe   Northern Europe     NaN       NaN       NaN
# Estonia          EST    Europe   Northern Europe     NaN       NaN       NaN
# Finland          FIN    Europe   Northern Europe     NaN       NaN       NaN
# France           FRA    Europe    Western Europe     NaN       NaN       NaN
# Germany          DEU    Europe    Western Europe     NaN       NaN  4.000000
# Greece           GRC    Europe   Southern Europe     NaN       NaN  0.000000
# Hungary          HUN    Europe    Eastern Europe     NaN       NaN       NaN
# Iceland          ISL    Europe   Northern Europe     NaN       NaN       NaN
# Italy            ITA    Europe   Southern Europe     NaN       NaN       NaN
# Latvia           LVA    Europe   Northern Europe     NaN       NaN       NaN
# Lithuania        LTU    Europe   Northern Europe     NaN       NaN       NaN
# Luxembourg       LUX    Europe    Western Europe     NaN       NaN       NaN
# Macedonia        MKD    Europe   Southern Europe     NaN       NaN       NaN
# Montenegro       MNE    Europe   Southern Europe     NaN       NaN       NaN
# Netherlands      NLD    Europe    Western Europe     NaN       NaN       NaN
# Norway           NOR    Europe   Northern Europe     NaN       NaN       NaN
# Poland           POL    Europe    Eastern Europe     NaN -1.000000 -2.000000
# Portugal         PRT    Europe   Southern Europe     NaN  4.000000       NaN
# Romania          ROU    Europe    Eastern Europe  -4.000  1.666667       NaN
# Slovak Republic  SVK    Europe    Eastern Europe     NaN       NaN       NaN
# Slovenia         SVN    Europe   Southern Europe     NaN       NaN       NaN
# Spain            ESP    Europe   Southern Europe     NaN       NaN       NaN
# Turkey           TUR      Asia      Western Asia     NaN       NaN       NaN
# United Kingdom   GBR    Europe   Northern Europe  -1.600  4.000000  2.454545
# United States    USA  Americas  Northern America   0.725  0.347826  0.277778
#
#                    201704    201705    201706    201707  ...    202208
# Albania               NaN       NaN       NaN       NaN  ...       NaN  \
# Belgium         -5.000000       NaN       NaN       NaN  ...       NaN
# Bulgaria              NaN       NaN       NaN       NaN  ...       NaN
# Canada                NaN -5.000000  2.500000  2.333333  ... -1.666667
# Croatia               NaN       NaN       NaN       NaN  ...       NaN
# Czech Republic  -3.000000       NaN       NaN       NaN  ... -3.000000
# Denmark               NaN       NaN       NaN       NaN  ...       NaN
# Estonia               NaN       NaN       NaN       NaN  ...  0.000000
# Finland               NaN       NaN       NaN       NaN  ...       NaN
# France          -5.000000 -2.428571       NaN       NaN  ... -3.250000
# Germany               NaN  0.000000 -0.333333  0.000000  ... -0.142857
# Greece                NaN       NaN       NaN       NaN  ...       NaN
# Hungary               NaN       NaN  4.000000       NaN  ...       NaN
# Iceland               NaN       NaN       NaN       NaN  ...       NaN
# Italy            3.000000  3.000000 -2.000000       NaN  ... -2.000000
# Latvia           0.000000       NaN       NaN       NaN  ...       NaN
# Lithuania             NaN       NaN       NaN       NaN  ...       NaN
# Luxembourg            NaN       NaN       NaN       NaN  ...       NaN
# Macedonia             NaN       NaN       NaN       NaN  ...       NaN
# Montenegro            NaN       NaN       NaN       NaN  ...       NaN
# Netherlands           NaN  4.000000       NaN       NaN  ...       NaN
# Norway                NaN       NaN       NaN       NaN  ...  1.000000
# Poland                NaN       NaN       NaN       NaN  ...       NaN
# Portugal              NaN       NaN       NaN       NaN  ...       NaN
# Romania               NaN       NaN       NaN -3.250000  ... -3.000000
# Slovak Republic       NaN       NaN       NaN       NaN  ...       NaN
# Slovenia         3.000000       NaN       NaN  3.000000  ...       NaN
# Spain                 NaN  1.000000  1.000000 -1.000000  ...       NaN
# Turkey           0.500000 -2.333333 -0.500000 -0.600000  ... -1.000000
# United Kingdom   2.750000  1.105263 -3.727273 -0.421053  ... -1.466667
# United States    0.175439 -0.699187 -0.509934 -0.552448  ... -2.030303
#
#                    202209    202210    202211    202212    202301    202302
# Albania               NaN       NaN       NaN       NaN       NaN       NaN  \
# Belgium               NaN       NaN -3.000000 -4.000000       NaN       NaN
# Bulgaria         4.000000       NaN       NaN       NaN       NaN       NaN
# Canada          -2.444444 -1.875000 -3.500000 -1.500000  1.000000 -2.375000
# Croatia               NaN       NaN       NaN       NaN       NaN       NaN
# Czech Republic  -1.000000       NaN       NaN       NaN       NaN -1.000000
# Denmark               NaN       NaN       NaN       NaN       NaN       NaN
# Estonia               NaN  0.000000       NaN -2.000000       NaN       NaN
# Finland               NaN       NaN       NaN       NaN       NaN       NaN
# France           1.000000 -1.250000 -1.250000 -1.666667  0.000000 -3.500000
# Germany         -0.666667 -0.111111  1.230769 -0.142857  1.111111 -0.285714
# Greece          -5.000000 -4.333333 -1.500000  1.000000 -2.333333 -1.000000
# Hungary          3.000000       NaN       NaN -1.000000  4.000000  4.000000
# Iceland               NaN       NaN       NaN       NaN       NaN       NaN
# Italy           -2.666667 -3.500000 -1.500000 -4.000000 -2.000000       NaN
# Latvia          -1.000000       NaN       NaN       NaN  6.000000       NaN
# Lithuania             NaN       NaN       NaN       NaN       NaN       NaN
# Luxembourg            NaN       NaN  4.000000 -5.500000       NaN       NaN
# Macedonia             NaN       NaN       NaN       NaN       NaN       NaN
# Montenegro            NaN       NaN       NaN       NaN       NaN       NaN
# Netherlands           NaN       NaN       NaN       NaN       NaN -6.000000
# Norway                NaN       NaN       NaN       NaN       NaN       NaN
# Poland          -3.000000       NaN -3.000000       NaN -2.000000       NaN
# Portugal              NaN       NaN       NaN       NaN       NaN       NaN
# Romania          0.000000 -3.000000 -4.333333 -3.000000 -2.000000       NaN
# Slovak Republic  4.000000       NaN       NaN       NaN       NaN       NaN
# Slovenia              NaN       NaN       NaN       NaN       NaN       NaN
# Spain                 NaN -3.000000  2.000000       NaN       NaN -1.000000
# Turkey          -3.000000 -3.333333  1.000000       NaN -2.333333 -3.000000
# United Kingdom  -2.411765 -1.090909 -3.066667 -0.909091 -1.666667 -0.857143
# United States   -1.523560 -1.392241 -0.851282 -1.047872 -1.782895 -1.753012
#
#                    202303    202304    202305
# Albania               NaN       NaN       NaN
# Belgium         -3.000000       NaN       NaN
# Bulgaria        -4.000000       NaN       NaN
# Canada          -2.000000 -3.000000 -1.000000
# Croatia               NaN       NaN       NaN
# Czech Republic        NaN       NaN       NaN
# Denmark               NaN       NaN       NaN
# Estonia               NaN       NaN       NaN
# Finland               NaN       NaN       NaN
# France           0.500000 -1.666667 -2.000000
# Germany          1.666667  2.000000       NaN
# Greece           0.000000       NaN -5.000000
# Hungary               NaN       NaN       NaN
# Iceland               NaN       NaN       NaN
# Italy                 NaN       NaN -3.000000
# Latvia                NaN       NaN       NaN
# Lithuania             NaN       NaN       NaN
# Luxembourg            NaN       NaN       NaN
# Macedonia             NaN       NaN       NaN
# Montenegro            NaN       NaN       NaN
# Netherlands           NaN       NaN       NaN
# Norway                NaN       NaN       NaN
# Poland                NaN  0.000000       NaN
# Portugal              NaN       NaN       NaN
# Romania         -1.000000 -1.500000       NaN
# Slovak Republic       NaN       NaN       NaN
# Slovenia              NaN       NaN       NaN
# Spain                 NaN -1.000000       NaN
# Turkey                NaN -1.333333       NaN
# United Kingdom  -1.357143 -3.111111 -1.000000
# United States   -1.195000 -0.797546 -1.538462
#
# [31 rows x 80 columns]

# %% [markdown]
# #### Visualise

# %%
# melt the dataframe to long format
melted_df = pd.melt(nato_month_df.reset_index(), id_vars=['index', 'ISO3', 'Region', 'Sub-region'], var_name='Month-Year', value_name='Tone')
melted_df = melted_df.set_index('index')

# create the line chart
fig = px.line(melted_df, x='Month-Year', y='Tone', color=melted_df.index, title='Average Tone by NATO Country by Month-Year')
fig.show()

# %% [markdown]
# #### By Year

# %%
# Drop any rows with all NaN values in the tone columns
temp_df = nato_month_df.dropna(subset=nato_month_df.columns[3:], how='all')

# Reshape the dataframe to have a multi-level index of (Country, Year-Month) and a single 'Tone' column
temp_df = temp_df.melt(id_vars=['ISO3', 'Region', 'Sub-region'], var_name='Year-Month', value_name='Tone')
temp_df = temp_df.set_index(['ISO3', 'Year-Month'])

# Extract the year from the Year-Month column and add it as a separate column
temp_df['Year'] = temp_df.index.get_level_values(1).str.slice(0, 4)

# Group by Country and Year, and take the mean tone value
nato_year_df = temp_df.groupby(['ISO3', 'Year', 'Region', 'Sub-region']).mean().reset_index()

# Pivot the dataframe so that the tone values are in columns labeled by year
nato_year_df = nato_year_df.pivot(index=['ISO3', 'Region', 'Sub-region'], columns='Year', values='Tone').reset_index()

# Rename the columns to add a prefix to the year
nato_year_df.columns = ['ISO3', 'Region', 'Sub-region'] + [str(col) for col in nato_year_df.columns[3:]]

# Rename index to country name
iso3_to_country = nato_month_df.reset_index().set_index('ISO3')['index'].to_dict()
nato_year_df.index = nato_year_df['ISO3'].map(iso3_to_country)
nato_year_df.index.name = None

nato_year_df
# Out:
#                 ISO3    Region        Sub-region      2017      2018
# Albania          ALB    Europe   Southern Europe       NaN  0.000000  \
# Belgium          BEL    Europe    Western Europe -4.666667 -1.718750
# Bulgaria         BGR    Europe    Eastern Europe  4.500000  1.333333
# Canada           CAN  Americas  Northern America -1.166667 -2.277273
# Czech Republic   CZE    Europe    Eastern Europe -3.000000 -0.500000
# Germany          DEU    Europe    Western Europe  1.264550  1.151389
# Denmark          DNK    Europe   Northern Europe  5.000000       NaN
# Spain            ESP    Europe   Southern Europe  0.642857  1.568750
# Estonia          EST    Europe   Northern Europe       NaN  0.000000
# Finland          FIN    Europe   Northern Europe  6.000000 -5.000000
# France           FRA    Europe    Western Europe -1.232143 -1.073909
# United Kingdom   GBR    Europe   Northern Europe  0.277438 -1.001832
# Greece           GRC    Europe   Southern Europe -1.000000  0.000000
# Croatia          HRV    Europe   Southern Europe       NaN       NaN
# Hungary          HUN    Europe    Eastern Europe  2.000000  1.041667
# Iceland          ISL    Europe   Northern Europe       NaN       NaN
# Italy            ITA    Europe   Southern Europe  2.111111  1.010417
# Lithuania        LTU    Europe   Northern Europe       NaN       NaN
# Luxembourg       LUX    Europe    Western Europe  0.000000  1.375000
# Latvia           LVA    Europe   Northern Europe  0.000000  0.000000
# Macedonia        MKD    Europe   Southern Europe       NaN       NaN
# Montenegro       MNE    Europe   Southern Europe  2.000000       NaN
# Netherlands      NLD    Europe    Western Europe  4.000000       NaN
# Norway           NOR    Europe   Northern Europe       NaN -2.500000
# Poland           POL    Europe    Eastern Europe -1.250000 -0.500000
# Portugal         PRT    Europe   Southern Europe  4.000000  0.000000
# Romania          ROU    Europe    Eastern Europe -1.645833  0.000000
# Slovak Republic  SVK    Europe    Eastern Europe       NaN  0.000000
# Slovenia         SVN    Europe   Southern Europe  3.000000  4.000000
# Turkey           TUR      Asia      Western Asia -0.718519 -0.696970
# United States    USA  Americas  Northern America -0.321012 -1.335883
#
#                      2019      2020      2021      2022      2023
# Albania               NaN  0.800000       NaN       NaN       NaN
# Belgium         -0.766667 -0.036667 -0.785714 -3.500000 -3.000000
# Bulgaria         2.000000  2.000000       NaN  4.000000 -4.000000
# Canada          -3.041682 -3.049074 -2.222603 -1.991204 -1.475000
# Czech Republic  -0.333333       NaN -1.000000 -2.380952 -1.000000
# Germany         -0.781355 -1.119420 -1.087336 -0.527830  1.123016
# Denmark          1.000000       NaN       NaN       NaN       NaN
# Spain            0.515152 -2.250000 -0.150000  0.250000 -1.000000
# Estonia          0.000000 -1.000000  0.500000 -0.666667       NaN
# Finland          3.000000       NaN       NaN       NaN       NaN
# France          -1.714646 -2.291667 -1.406025 -1.807639 -1.333333
# United Kingdom  -0.944826 -1.567449 -2.073467 -2.310041 -1.598413
# Greece          -3.055556 -0.340000 -2.135417 -2.208333 -2.083333
# Croatia               NaN -2.000000       NaN       NaN       NaN
# Hungary          1.000000  0.500000  1.000000  1.000000  4.000000
# Iceland         -0.333333       NaN       NaN       NaN       NaN
# Italy            0.259259 -1.291667 -2.041667 -1.736111 -2.500000
# Lithuania       -3.000000 -0.750000 -2.250000       NaN       NaN
# Luxembourg      -0.888889 -5.000000 -0.750000 -2.100000       NaN
# Latvia                NaN  0.000000       NaN -1.000000  6.000000
# Macedonia             NaN -1.000000       NaN       NaN       NaN
# Montenegro            NaN       NaN       NaN       NaN       NaN
# Netherlands      3.000000 -9.000000  1.000000       NaN -6.000000
# Norway           0.000000       NaN -2.500000  0.000000       NaN
# Poland          -2.040909 -1.770833 -0.300000 -2.666667 -1.000000
# Portugal         1.000000 -0.500000  3.000000  3.000000       NaN
# Romania         -2.650000 -1.750000 -1.425926 -2.454545 -1.500000
# Slovak Republic       NaN       NaN       NaN  4.000000       NaN
# Slovenia         1.000000       NaN  0.000000  5.000000       NaN
# Turkey          -1.337698 -1.443723 -0.440278 -2.233333 -2.222222
# United States   -1.670643 -2.147242 -1.862698 -1.748659 -1.413383

# %%
# Drop rows that are not in NATO from country_df
nato_countries = ['Albania', 'Belgium', 'Bulgaria', 'Canada', 'Croatia', 'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
                  'Iceland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway', 'Poland', 'Portugal',
                  'Romania', 'Slovakia', 'Slovenia', 'Spain', 'Turkey', 'United Kingdom', 'United States']

nato_country_df = country_df[country_df['Country'].isin(nato_countries)]
nato_country_df.drop(['Count_range'], axis=1, inplace=True)

fig = px.choropleth(nato_country_df,
                    locations="Country",
                    color="Average Tone",
                    hover_data={"Country": False,
                                "Count": True,
                                "Year": False,
                                "Average Tone": True},
                    hover_name="Country", # column to add to hover information
                    locationmode="country names",
                    animation_frame="Year",
                    color_discrete_map=px.colors.sequential.Plasma
                    )

fig.update_layout(
    autosize=False,
    width=1200,
    height=800,)

fig.show()
# Out:
# <ipython-input-27-688564546a02>:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# melt the dataframe to long format
melted_df = pd.melt(nato_year_df.reset_index(), id_vars=['index', 'ISO3', 'Region', 'Sub-region'], var_name='Year', value_name='Tone')
melted_df = melted_df.set_index('index')

# create the line chart
fig = px.line(melted_df, x='Year', y='Tone', color=melted_df.index, title='Average Tone by NATO Country by Year')
fig.show()

# %%
nato_year_df
# Out:
#                 ISO3    Region        Sub-region      2017      2018
# Albania          ALB    Europe   Southern Europe       NaN  0.000000  \
# Belgium          BEL    Europe    Western Europe -4.666667 -1.718750
# Bulgaria         BGR    Europe    Eastern Europe  4.500000  1.333333
# Canada           CAN  Americas  Northern America -1.166667 -2.277273
# Czech Republic   CZE    Europe    Eastern Europe -3.000000 -0.500000
# Germany          DEU    Europe    Western Europe  1.264550  1.151389
# Denmark          DNK    Europe   Northern Europe  5.000000       NaN
# Spain            ESP    Europe   Southern Europe  0.642857  1.568750
# Estonia          EST    Europe   Northern Europe       NaN  0.000000
# Finland          FIN    Europe   Northern Europe  6.000000 -5.000000
# France           FRA    Europe    Western Europe -1.232143 -1.073909
# United Kingdom   GBR    Europe   Northern Europe  0.277438 -1.001832
# Greece           GRC    Europe   Southern Europe -1.000000  0.000000
# Croatia          HRV    Europe   Southern Europe       NaN       NaN
# Hungary          HUN    Europe    Eastern Europe  2.000000  1.041667
# Iceland          ISL    Europe   Northern Europe       NaN       NaN
# Italy            ITA    Europe   Southern Europe  2.111111  1.010417
# Lithuania        LTU    Europe   Northern Europe       NaN       NaN
# Luxembourg       LUX    Europe    Western Europe  0.000000  1.375000
# Latvia           LVA    Europe   Northern Europe  0.000000  0.000000
# Macedonia        MKD    Europe   Southern Europe       NaN       NaN
# Montenegro       MNE    Europe   Southern Europe  2.000000       NaN
# Netherlands      NLD    Europe    Western Europe  4.000000       NaN
# Norway           NOR    Europe   Northern Europe       NaN -2.500000
# Poland           POL    Europe    Eastern Europe -1.250000 -0.500000
# Portugal         PRT    Europe   Southern Europe  4.000000  0.000000
# Romania          ROU    Europe    Eastern Europe -1.645833  0.000000
# Slovak Republic  SVK    Europe    Eastern Europe       NaN  0.000000
# Slovenia         SVN    Europe   Southern Europe  3.000000  4.000000
# Turkey           TUR      Asia      Western Asia -0.718519 -0.696970
# United States    USA  Americas  Northern America -0.321012 -1.335883
#
#                      2019      2020      2021      2022      2023
# Albania               NaN  0.800000       NaN       NaN       NaN
# Belgium         -0.766667 -0.036667 -0.785714 -3.500000 -3.000000
# Bulgaria         2.000000  2.000000       NaN  4.000000 -4.000000
# Canada          -3.041682 -3.049074 -2.222603 -1.991204 -1.475000
# Czech Republic  -0.333333       NaN -1.000000 -2.380952 -1.000000
# Germany         -0.781355 -1.119420 -1.087336 -0.527830  1.123016
# Denmark          1.000000       NaN       NaN       NaN       NaN
# Spain            0.515152 -2.250000 -0.150000  0.250000 -1.000000
# Estonia          0.000000 -1.000000  0.500000 -0.666667       NaN
# Finland          3.000000       NaN       NaN       NaN       NaN
# France          -1.714646 -2.291667 -1.406025 -1.807639 -1.333333
# United Kingdom  -0.944826 -1.567449 -2.073467 -2.310041 -1.598413
# Greece          -3.055556 -0.340000 -2.135417 -2.208333 -2.083333
# Croatia               NaN -2.000000       NaN       NaN       NaN
# Hungary          1.000000  0.500000  1.000000  1.000000  4.000000
# Iceland         -0.333333       NaN       NaN       NaN       NaN
# Italy            0.259259 -1.291667 -2.041667 -1.736111 -2.500000
# Lithuania       -3.000000 -0.750000 -2.250000       NaN       NaN
# Luxembourg      -0.888889 -5.000000 -0.750000 -2.100000       NaN
# Latvia                NaN  0.000000       NaN -1.000000  6.000000
# Macedonia             NaN -1.000000       NaN       NaN       NaN
# Montenegro            NaN       NaN       NaN       NaN       NaN
# Netherlands      3.000000 -9.000000  1.000000       NaN -6.000000
# Norway           0.000000       NaN -2.500000  0.000000       NaN
# Poland          -2.040909 -1.770833 -0.300000 -2.666667 -1.000000
# Portugal         1.000000 -0.500000  3.000000  3.000000       NaN
# Romania         -2.650000 -1.750000 -1.425926 -2.454545 -1.500000
# Slovak Republic       NaN       NaN       NaN  4.000000       NaN
# Slovenia         1.000000       NaN  0.000000  5.000000       NaN
# Turkey          -1.337698 -1.443723 -0.440278 -2.233333 -2.222222
# United States   -1.670643 -2.147242 -1.862698 -1.748659 -1.413383

# %%
import seaborn as sns
import matplotlib. pyplot as plt 

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(30,15))

# By Year
numeric_cols = nato_year_df.select_dtypes(include=['float64', 'int64']).columns
df_numeric = nato_year_df[numeric_cols]

# transpose the DataFrame
df_t = df_numeric.T

# compute the correlation matrix
corr_matrix = df_t.corr()

# plot the heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', ax=ax1)

# By Month
numeric_cols = nato_month_df.select_dtypes(include=['float64', 'int64']).columns
df_numeric = nato_month_df[numeric_cols]

# transpose the DataFrame
df_t = df_numeric.T

# compute the correlation matrix
corr_matrix = df_t.corr()

# plot the heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', ax=ax2)

ax1.title.set_text('Correlation Matrix by Year')
ax2.title.set_text('Correlation Matrix by Month')
plt.show()

# %% [markdown]
# #### Drop any rows with NaN values in the tone columns

# %% [markdown]
# #save csv
# nato_year_df.to_csv('./csv/nato_year_df.csv')

# %%
# Drop rows as long as NaN is present in any of the tone columns
temp_df = nato_year_df.dropna(subset=nato_year_df.columns[3:])

# melt the dataframe to long format
melted_df = pd.melt(temp_df.reset_index(), id_vars=['index', 'ISO3', 'Region', 'Sub-region'], var_name='Year', value_name='Tone')
melted_df = melted_df.set_index('index')

# create the line chart
fig = px.line(melted_df, x='Year', y='Tone', color=melted_df.index, title='Average Tone by NATO Countries by Year')
fig.show()



# By Year
numeric_cols = temp_df.select_dtypes(include=['float64', 'int64']).columns
df_numeric = temp_df[numeric_cols]

# transpose the DataFrame
df_t = df_numeric.T

# compute the correlation matrix
corr_matrix = df_t.corr()

# plot the heatmap
plt.figure(figsize=(10,10))
plt.title('Correlation Matrix of NATO by Year')
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True, fmt=".1f")

plt.show()

# %%
fig = px.scatter(melted_df, x="Year", y="Tone", color=melted_df.index, title="Average Tone by NATO Countries by Year")
fig.show()

# %% [markdown]
# #### Show percentage change per year

# %%
cm = sns.light_palette("green", as_cmap=True)

# %%
diff_df = nato_year_df.iloc[:,3:].diff(axis=1)

# Drop the first column since there's no previous year to compare
diff_df = diff_df.drop(columns=['2017'])

def color_negative_red(val):
    color = 'red' if val < 0 else 'green' if val > 0  else 'grey'
    return f'background-color: {color}'

diff_df.style.applymap(color_negative_red)
# Out:
# <style type="text/css">
# #T_8e865_row0_col0, #T_8e865_row0_col1, #T_8e865_row0_col2, #T_8e865_row0_col3, #T_8e865_row0_col4, #T_8e865_row0_col5, #T_8e865_row2_col2, #T_8e865_row2_col3, #T_8e865_row2_col4, #T_8e865_row4_col2, #T_8e865_row4_col3, #T_8e865_row6_col0, #T_8e865_row6_col1, #T_8e865_row6_col2, #T_8e865_row6_col3, #T_8e865_row6_col4, #T_8e865_row6_col5, #T_8e865_row8_col0, #T_8e865_row8_col1, #T_8e865_row8_col5, #T_8e865_row9_col2, #T_8e865_row9_col3, #T_8e865_row9_col4, #T_8e865_row9_col5, #T_8e865_row13_col0, #T_8e865_row13_col1, #T_8e865_row13_col2, #T_8e865_row13_col3, #T_8e865_row13_col4, #T_8e865_row13_col5, #T_8e865_row14_col4, #T_8e865_row15_col0, #T_8e865_row15_col1, #T_8e865_row15_col2, #T_8e865_row15_col3, #T_8e865_row15_col4, #T_8e865_row15_col5, #T_8e865_row17_col0, #T_8e865_row17_col1, #T_8e865_row17_col4, #T_8e865_row17_col5, #T_8e865_row18_col5, #T_8e865_row19_col0, #T_8e865_row19_col1, #T_8e865_row19_col2, #T_8e865_row19_col3, #T_8e865_row19_col4, #T_8e865_row20_col0, #T_8e865_row20_col1, #T_8e865_row20_col2, #T_8e865_row20_col3, #T_8e865_row20_col4, #T_8e865_row20_col5, #T_8e865_row21_col0, #T_8e865_row21_col1, #T_8e865_row21_col2, #T_8e865_row21_col3, #T_8e865_row21_col4, #T_8e865_row21_col5, #T_8e865_row22_col0, #T_8e865_row22_col1, #T_8e865_row22_col4, #T_8e865_row22_col5, #T_8e865_row23_col0, #T_8e865_row23_col2, #T_8e865_row23_col3, #T_8e865_row23_col5, #T_8e865_row25_col4, #T_8e865_row25_col5, #T_8e865_row27_col0, #T_8e865_row27_col1, #T_8e865_row27_col2, #T_8e865_row27_col3, #T_8e865_row27_col4, #T_8e865_row27_col5, #T_8e865_row28_col2, #T_8e865_row28_col3, #T_8e865_row28_col5 {
#   background-color: grey;
# }
# #T_8e865_row1_col0, #T_8e865_row1_col1, #T_8e865_row1_col2, #T_8e865_row1_col5, #T_8e865_row2_col1, #T_8e865_row3_col3, #T_8e865_row3_col4, #T_8e865_row3_col5, #T_8e865_row4_col0, #T_8e865_row4_col1, #T_8e865_row4_col5, #T_8e865_row5_col3, #T_8e865_row5_col4, #T_8e865_row5_col5, #T_8e865_row7_col0, #T_8e865_row7_col3, #T_8e865_row7_col4, #T_8e865_row8_col3, #T_8e865_row9_col1, #T_8e865_row10_col0, #T_8e865_row10_col3, #T_8e865_row10_col5, #T_8e865_row11_col1, #T_8e865_row11_col5, #T_8e865_row12_col0, #T_8e865_row12_col2, #T_8e865_row12_col5, #T_8e865_row14_col3, #T_8e865_row14_col5, #T_8e865_row16_col4, #T_8e865_row17_col2, #T_8e865_row18_col0, #T_8e865_row18_col3, #T_8e865_row19_col5, #T_8e865_row22_col3, #T_8e865_row23_col1, #T_8e865_row23_col4, #T_8e865_row24_col0, #T_8e865_row24_col2, #T_8e865_row24_col3, #T_8e865_row24_col5, #T_8e865_row25_col1, #T_8e865_row25_col3, #T_8e865_row26_col0, #T_8e865_row26_col2, #T_8e865_row26_col3, #T_8e865_row26_col5, #T_8e865_row28_col0, #T_8e865_row28_col4, #T_8e865_row29_col0, #T_8e865_row29_col3, #T_8e865_row29_col5, #T_8e865_row30_col3, #T_8e865_row30_col4, #T_8e865_row30_col5 {
#   background-color: green;
# }
# #T_8e865_row1_col3, #T_8e865_row1_col4, #T_8e865_row2_col0, #T_8e865_row2_col5, #T_8e865_row3_col0, #T_8e865_row3_col1, #T_8e865_row3_col2, #T_8e865_row4_col4, #T_8e865_row5_col0, #T_8e865_row5_col1, #T_8e865_row5_col2, #T_8e865_row7_col1, #T_8e865_row7_col2, #T_8e865_row7_col5, #T_8e865_row8_col2, #T_8e865_row8_col4, #T_8e865_row9_col0, #T_8e865_row10_col1, #T_8e865_row10_col2, #T_8e865_row10_col4, #T_8e865_row11_col0, #T_8e865_row11_col2, #T_8e865_row11_col3, #T_8e865_row11_col4, #T_8e865_row12_col1, #T_8e865_row12_col3, #T_8e865_row12_col4, #T_8e865_row14_col0, #T_8e865_row14_col1, #T_8e865_row14_col2, #T_8e865_row16_col0, #T_8e865_row16_col1, #T_8e865_row16_col2, #T_8e865_row16_col3, #T_8e865_row16_col5, #T_8e865_row17_col3, #T_8e865_row18_col1, #T_8e865_row18_col2, #T_8e865_row18_col4, #T_8e865_row22_col2, #T_8e865_row24_col1, #T_8e865_row24_col4, #T_8e865_row25_col0, #T_8e865_row25_col2, #T_8e865_row26_col1, #T_8e865_row26_col4, #T_8e865_row28_col1, #T_8e865_row29_col1, #T_8e865_row29_col2, #T_8e865_row29_col4, #T_8e865_row30_col0, #T_8e865_row30_col1, #T_8e865_row30_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_8e865">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e865_level0_col0" class="col_heading level0 col0" >2018</th>
#       <th id="T_8e865_level0_col1" class="col_heading level0 col1" >2019</th>
#       <th id="T_8e865_level0_col2" class="col_heading level0 col2" >2020</th>
#       <th id="T_8e865_level0_col3" class="col_heading level0 col3" >2021</th>
#       <th id="T_8e865_level0_col4" class="col_heading level0 col4" >2022</th>
#       <th id="T_8e865_level0_col5" class="col_heading level0 col5" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e865_level0_row0" class="row_heading level0 row0" >Albania</th>
#       <td id="T_8e865_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_8e865_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_8e865_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_8e865_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_8e865_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_8e865_row0_col5" class="data row0 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8e865_level0_row1" class="row_heading level0 row1" >Belgium</th>
#       <td id="T_8e865_row1_col0" class="data row1 col0" >2.947917</td>
#       <td id="T_8e865_row1_col1" class="data row1 col1" >0.952083</td>
#       <td id="T_8e865_row1_col2" class="data row1 col2" >0.730000</td>
#       <td id="T_8e865_row1_col3" class="data row1 col3" >-0.749048</td>
#       <td id="T_8e865_row1_col4" class="data row1 col4" >-2.714286</td>
#       <td id="T_8e865_row1_col5" class="data row1 col5" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_8e865_level0_row2" class="row_heading level0 row2" >Bulgaria</th>
#       <td id="T_8e865_row2_col0" class="data row2 col0" >-3.166667</td>
#       <td id="T_8e865_row2_col1" class="data row2 col1" >0.666667</td>
#       <td id="T_8e865_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_8e865_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_8e865_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_8e865_row2_col5" class="data row2 col5" >-8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8e865_level0_row3" class="row_heading level0 row3" >Canada</th>
#       <td id="T_8e865_row3_col0" class="data row3 col0" >-1.110606</td>
#       <td id="T_8e865_row3_col1" class="data row3 col1" >-0.764409</td>
#       <td id="T_8e865_row3_col2" class="data row3 col2" >-0.007392</td>
#       <td id="T_8e865_row3_col3" class="data row3 col3" >0.826471</td>
#       <td id="T_8e865_row3_col4" class="data row3 col4" >0.231399</td>
#       <td id="T_8e865_row3_col5" class="data row3 col5" >0.516204</td>
#     </tr>
#     <tr>
#       <th id="T_8e865_level0_row4" class="row_heading level0 row4" >Czech Republic</th>
#       <td id="T_8e865_row4_col0" class="data row4 col0" >2.500000</td>
#       <td id="T_8e865_row4_col1" class="data row4 col1" >0.166667</td>
#       <td id="T_8e865_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_8e865_row4_col3" class="data row4 col3" >nan</td>
#       <td id="T_8e865_row4_col4" class="data row4 col4" >-1.380952</td>
#       <td id="T_8e865_row4_col5" class="data row4 col5" >1.380952</td>
#     </tr>
#     <tr>
#       <th id="T_8e865_level0_row5" class="row_heading level0 row5" >Germany</th>
#       <td id="T_8e865_row5_col0" class="data row5 col0" >-0.113161</td>
#       <td id="T_8e865_row5_col1" class="data row5 col1" >-1.932744</td>
#       <td id="T_8e865_row5_col2" class="data row5 col2" >-0.338065</td>
#       <td id="T_8e865_row5_col3" class="data row5 col3" >0.032084</td>
#       <td id="T_8e865_row5_col4" class="data row5 col4" >0.559506</td>
#       <td id="T_8e865_row5_col5" class="data row5 col5" >1.650845</td>
#     </tr>
#     <tr>
#       <th id="T_8e865_level0_row6" class="row_heading level0 row6" >Denmark</th>
#       <td id="T_8e865_row6_col0" class="data row6 col0" >nan</td>
#       <td id="T_8e865_row6_col1" class="data row6 col1" >nan</td>
#       <td id="T_8e865_row6_col2" class="data row6 col2" >nan</td>
#       <td id="T_8e865_row6_col3" class=
